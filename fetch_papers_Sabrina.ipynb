# %% [markdown]
# ## Task Force A: Fetching PubMed ID's from queries

# %%
from Bio import Entrez
import csv

# %% [markdown]
# ### Step 1: Make function to search for papers and return their PubMED IDs

# %%
def search_pubmed_for_ids(query, max_results=13):
    Entrez.email = "zeynep.korkmaz@tum.de"  # Set email address

    handle = Entrez.esearch(db="pubmed", term=query, retmax=max_results)
    record = Entrez.read(handle)
    handle.close()

    return record["IdList"]

# %%
# Example query
search_pubmed_for_ids("Helicobacter[Organsim] NOT IBD NOT intestinal microbes")
# Out:
# ['38154380', '38153379', '38153067', '38152823', '38151822', '38148080', '38147967', '38147044', '38146380', '38145041', '38144880', '38143438', '38140941', '38140410', '38139349', '38139130', '38137996', '38137213', '38136706', '38136703']

# %% [markdown]
# ### Step 2: Create the keyword and query list from the csv file

# %%
def read_keywords_from_csv(csv_file):
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)

        keywords_dict = {}
        
        current_pub_title = None
        current_keywords = []
        current_sq_tp = []
        current_sq_fp = []
        current_sq_r = []

        for row in reader:
            
            # Remove trailing commas from each element in the row
            row = [item.strip(', ') for item in row]
            
            if row and not row[0].isdigit():  # Skip numeric rows
                if row[0] == "Pub Title":
                    if current_pub_title:
                        # create for every title/DOI keys
                        keywords_dict[current_pub_title] = {
                            "Pub Title": current_pub_title,
                            "Keywords": current_keywords,
                            "SQ_TP": current_sq_tp,
                            "SQ_FP": current_sq_fp,
                            "SQ_R": current_sq_r
                        }
                    current_pub_title = row[1]
                    current_keywords = []
                    current_sq_tp = []
                    current_sq_fp = []
                    current_sq_r = []
                    # add values to list of the different keys and check for empty entries
                elif row[0] == "Keywords":
                    current_keywords.extend(item for item in row[1:] if item)
                elif row[0] == "SQ_TP":
                    current_sq_tp.extend(item for item in row[1:] if item)
                elif row[0] == "SQ_FP":
                    current_sq_fp.extend(item for item in row[1:] if item)
                elif row[0] == "SQ_R":
                    current_sq_r.extend(item for item in row[1:] if item)

        # Add the last entry
        if current_pub_title:
            keywords_dict[current_pub_title] = {
                "Pub Title": current_pub_title,
                "Keywords": current_keywords,
                "SQ_TP": current_sq_tp,
                "SQ_FP": current_sq_fp,
                "SQ_R": current_sq_r
            }

    return keywords_dict

# %% [markdown]
# ##### How the dictionary looks:

# %%
# save csv file
input_csv = "NLP_Sabrina.csv"

# %%
# create dictionary from csv
keywords_dict = read_keywords_from_csv(input_csv)

# %% [markdown]
# # print dictionary
# keywords_dict

# %% [markdown]
# ##### Other representation of the dictionary for testing and debugging purposes

# %% [markdown]
# for pub_title, data in keywords_dict.items():
#             print(f"Pub Title: {data['Pub Title']}")
#             print(f"Keywords: {', '.join(data['Keywords'])}")
#             print(f"SQ_TP: {', '.join(data['SQ_TP'])}")
#             print(f"SQ_FP: {', '.join(data['SQ_FP'])}")
#             print(f"SQ_R: {', '.join(data['SQ_R'])}")
#             print("\n" + "=" * 80 + "\n")  # Separator between entries

# %% [markdown]
# ### Step 3: Use dictionary with queries as input and fetch PubMED IDs.
# #### Option 1: This option is more comprehensive since it also saves the used queries in the dictionary.

# %%
def dict_to_pubmed_id(input_dict):
    # Initialize a new dictionary to store the results
    result_dict = {}

    # Iterate over each publication entry in the input dictionary
    for pub_title, pub_data in input_dict.items():
        # Create a copy of the publication data
        pub_result = pub_data.copy()

        # Initialize empty lists for PubMed IDs for SQ_TP, SQ_FP, and SQ_R
        pub_result['PubMed_IDs_TP'] = []
        pub_result['PubMed_IDs_FP'] = []
        pub_result['PubMed_IDs_R'] = []

        # Extract elements from SQ_TP, SQ_FP, and SQ_R lists and search PubMed for IDs
        for sq_tp_element in pub_data['SQ_TP']:
            pub_result['PubMed_IDs_TP'].extend(search_pubmed_for_ids(sq_tp_element))

        for sq_fp_element in pub_data['SQ_FP']:
            pub_result['PubMed_IDs_FP'].extend(search_pubmed_for_ids(sq_fp_element))

        for sq_r_element in pub_data['SQ_R']:
            pub_result['PubMed_IDs_R'].extend(search_pubmed_for_ids(sq_r_element))

        # Add the modified publication data to the result dictionary
        result_dict[pub_title] = pub_result

    return result_dict

# %%
result_dict = dict_to_pubmed_id(keywords_dict)
result_dict
# Out:
# {'https://dx.doi.org/10.3390/nu15030636': {'Pub Title': 'https://dx.doi.org/10.3390/nu15030636',
#   'Keywords': ['intestinal microbes',
#    'cecal enlargement',
#    'germ-free animal models',
#    'digestive enzymes',
#    'amino acid metabolism',
#    'Helicobacter sp.',
#    'Rodientibacter sp.',
#    'Staphylococcus aureus',
#    'Pseudomonas aeruginosa',
#    'antibiotic treatment'],
#   'SQ_TP': ['intestinal microbes AND IBD',
#    'Helicobacter[Organism] AND IBD',
#    'germ-free animal models AND Heliobacter[Organism] and IBD',
#    'germ-free animal models AND Staphylococcus[Organism] and IBD'],
#   'SQ_FP': ['cecal enlargement AND amino acid metabolism',
#    'Helicobacter[Organsim] NOT IBD NOT intestinal microbes'],
#   'SQ_R': ['amino acid metabolism AND IBD',
#    'cecal enlargement NOT IBD AND antibiotic treatment',
#    'cecal enlargement AND digestive enzymes NOT IBD NOT intestinal microbes AND antibiotic treatment'],
#   'PubMed_IDs_TP': ['38124090',
#    '38078655',
#    '38075846',
#    '38059748',
#    '37876938',
#    '37868553',
#    '37865178',
#    '37849728',
#    '37842919',
#    '37842912',
#    '37822139',
#    '37819377',
#    '37795305',
#    '38073022',
#    '37955225',
#    '37917397',
#    '37873782',
#    '37732778',
#    '37682136',
#    '37662864',
#    '37523213',
#    '37507636',
#    '37463350',
#    '37274071',
#    '37197438',
#    '36873123'],
#   'PubMed_IDs_FP': ['36771343',
#    '30353943',
#    '24782618',
#    '19176351',
#    '7516124',
#    '12616301',
#    '1732475',
#    '6084087',
#    '870567',
#    '38154380',
#    '38153379',
#    '38153067',
#    '38152823',
#    '38151822',
#    '38148080',
#    '38147967',
#    '38147044',
#    '38146380',
#    '38145041',
#    '38144880',
#    '38143438',
#    '38140941'],
#   'PubMed_IDs_R': ['38069446',
#    '38044504',
#    '37936710',
#    '37909786',
#    '37848760',
#    '37820403',
#    '37699041',
#    '37660064',
#    '37634772',
#    '37577725',
#    '37536268',
#    '37481182',
#    '37447212',
#    '37209652',
#    '36096456',
#    '35738141',
#    '35704618',
#    '35307731',
#    '34388231',
#    '33402156',
#    '32625197',
#    '32062121',
#    '32017595',
#    '31229072',
#    '30921220',
#    '30353943',
#    '11400308',
#    '4318245']},
#  'https://dx.doi.org/10.1016/j.tim.2023.02.009': {'Pub Title': 'https://dx.doi.org/10.1016/j.tim.2023.02.009',
#   'Keywords': ['fasting',
#    'gut microbiome',
#    'autophagy',
#    '16S rRNA gene amplicon sequencing',
#    'self-reporting methods',
#    'food-frequency questionnaires'],
#   'SQ_TP': ['gut microbiome AND IBD'],
#   'SQ_FP': ['fasting AND autophagy NOT gut microbiome',
#    '16S rRNA gene amplicon sequencing AND self-reporting methods AND food-frequency questionnaires',
#    'autophagy NOT IBD NOT gut microbiome'],
#   'SQ_R': ['gut microbiome AND autophagy NOT IBD',
#    'autophagy AND IBD NOT gut microbiome',
#    'fasting AND gut microbiome',
#    'fasting AND IBD',
#    'gut microbiome AND 16S rRNA gene amplicon sequencing'],
#   'PubMed_IDs_TP': ['38151490',
#    '38145852',
#    '38140362',
#    '38138026',
#    '38133321',
#    '38130639',
#    '38128748',
#    '38124090',
#    '38123972',
#    '38113381',
#    '38110547',
#    '38102104',
#    '38099679'],
#   'PubMed_IDs_FP': ['38136414',
#    '38132294',
#    '38118410',
#    '38020718',
#    '38018843',
#    '38018193',
#    '38013515',
#    '38002621',
#    '37994436',
#    '37979443',
#    '37960230',
#    '37945671',
#    '37924048',
#    '38154758',
#    '38154557',
#    '38154209',
#    '38154205',
#    '38154203',
#    '38155332',
#    '38155279',
#    '38153635',
#    '38153629',
#    '38153369',
#    '38153175',
#    '38152888',
#    '38152151'],
#   'PubMed_IDs_R': ['38127816',
#    '38093299',
#    '38055797',
#    '38054830',
#    '38042501',
#    '38016505',
#    '37995468',
#    '37976960',
#    '37898287',
#    '37889013',
#    '37884137',
#    '37804915',
#    '37779147',
#    '38136224',
#    '38070244',
#    '38030117',
#    '38002302',
#    '37968554',
#    '37884590',
#    '37837511',
#    '37797746',
#    '37748021',
#    '37723664',
#    '37691056',
#    '37669386',
#    '37554552',
#    '38154959',
#    '38137679',
#    '38134985',
#    '38124458',
#    '38068863',
#    '38068773',
#    '38053727',
#    '38042896',
#    '38040541',
#    '38034007',
#    '38026796',
#    '38026235',
#    '38005193',
#    '37930142',
#    '37764766',
#    '37739715',
#    '37713878',
#    '37664383',
#    '37624558',
#    '37284561',
#    '37139278',
#    '37078395',
#    '36999464',
#    '36771288',
#    '36632325',
#    '36618695',
#    '38145055',
#    '38129967',
#    '38124157',
#    '38116533',
#    '38110473',
#    '38098315',
#    '38097563',
#    '38088370',
#    '38074098',
#    '38049420',
#    '38031339',
#    '38029085',
#    '38019083']},
#  'https://dx.doi.org/10.1158/2159-8290.cd-22-0876': {'Pub Title': 'https://dx.doi.org/10.1158/2159-8290.cd-22-0876',
#   'Keywords': ['Immunotherapies',
#    'pancreatic ductal adenocarcinoma',
#    'immunosuppression',
#    'chemotherapy',
#    'chemoradiation',
#    'oncolytic virotherapy',
#    'vaccination',
#    'KRAS-directed therapies',
#    'oncogenic signaling',
#    'cell-type specific proteomics'],
#   'SQ_TP': ['IBD AND microbiome AND immunosuppression'],
#   'SQ_FP': ['immunosuppression AND pancreatic cancer OR oncolytic virotherapy',
#    'IBD AND oncolytic virotherapy',
#    'chemotherapy AND chemoradiation AND vaccination'],
#   'SQ_R': ['pancreatic cancer AND IBD OR immunosuppression AND IBD',
#    'KRAS-directed therapies AND IBD',
#    'cell-type specific proteomics AND IBD'],
#   'PubMed_IDs_TP': ['38137947',
#    '38107848',
#    '38044504',
#    '38018424',
#    '37916431',
#    '37859409',
#    '37849974',
#    '37629560',
#    '37586320',
#    '37565604',
#    '37481231',
#    '37454061',
#    '36992690'],
#   'PubMed_IDs_FP': ['38153634',
#    '38150172',
#    '38149454',
#    '38144356',
#    '38140619',
#    '38139207',
#    '38139100',
#    '38136254',
#    '38135348',
#    '38132457',
#    '38129797',
#    '38122949',
#    '38114117',
#    '37917174',
#    '37871379',
#    '37652484',
#    '37382632',
#    '37330155',
#    '37312782',
#    '37185402',
#    '37020749',
#    '36992198',
#    '36908679',
#    '36871535',
#    '36831702',
#    '36694348'],
#   'PubMed_IDs_R': ['38140629',
#    '38140252',
#    '38139373',
#    '38137947',
#    '38130948',
#    '38107848',
#    '38106709',
#    '38097396',
#    '38096793',
#    '38075867',
#    '38075846',
#    '38065612',
#    '38064812',
#    '37531774',
#    '35456018',
#    '34876703',
#    '34780721',
#    '33550886',
#    '32753478',
#    '32229654',
#    '31825833',
#    '31632367',
#    '31626754',
#    '31179321',
#    '31019191',
#    '30182050']},
#  'https://dx.doi.org/10.1016/j.xgen.2023.100276': {'Pub Title': 'https://dx.doi.org/10.1016/j.xgen.2023.100276',
#   'Keywords': ['genetic screening',
#    'non-coding genomics',
#    'cancer evolution',
#    'leukemia',
#    'lymphoma',
#    'mouse model',
#    'discrete gene dysregulation AND lymphoma AND leukmia',
#    'cell-type specific enhancer',
#    'tumor suppressors'],
#   'SQ_TP': ['IBD AND mouse model AND microbiome'],
#   'SQ_FP': ['leukemia and lymphoma NOT IBD',
#    'non-coding genomics AND genetic screening AND cancer evolution',
#    'mouse model AND tumor suppressors AND genetic screening AND non-coding genomics'],
#   'SQ_R': ['cancer evolution AND IBD',
#    'tumor suppressors AND IBD',
#    'IBD AND (mouse model OR genetic screening)'],
#   'PubMed_IDs_TP': ['38124090',
#    '38112525',
#    '38098663',
#    '38096941',
#    '38073022',
#    '38068850',
#    '38068838',
#    '38059748',
#    '38033588',
#    '38024289',
#    '38010872',
#    '38009836',
#    '38004116'],
#   'PubMed_IDs_FP': ['38149869',
#    '38148142',
#    '38134325',
#    '38127030',
#    '38124378',
#    '38123697',
#    '38117930',
#    '38112683',
#    '38112426',
#    '38110554',
#    '38109966',
#    '38102772',
#    '38101943',
#    '37946251',
#    '36950387',
#    '35850704',
#    '35248370',
#    '33822294',
#    '31518831',
#    '30787463',
#    '30239329',
#    '27725301',
#    '23376637',
#    '17033624'],
#   'PubMed_IDs_R': ['37941424',
#    '37732357',
#    '37566032',
#    '37322120',
#    '37190315',
#    '37009367',
#    '36995276',
#    '36765708',
#    '36448229',
#    '36430302',
#    '36388654',
#    '36195424',
#    '35951774',
#    '36353202',
#    '36002022',
#    '33807999',
#    '33247598',
#    '33225975',
#    '32673694',
#    '32037085',
#    '32019290',
#    '31534167',
#    '31054900',
#    '30989570',
#    '30269357',
#    '29147967',
#    '38149880',
#    '38147028',
#    '38140314',
#    '38138587',
#    '38124090',
#    '38113752',
#    '38113690',
#    '38112525',
#    '38111509',
#    '38110964',
#    '38110791',
#    '38098663',
#    '38097396']},
#  'https://dx.doi.org/10.1371/journal.pone.0280870': {'Pub Title': 'https://dx.doi.org/10.1371/journal.pone.0280870',
#   'Keywords': ['NGS-based testing',
#    'bacterial microbiota',
#    '16S rRNA gene',
#    'Actinobacteria',
#    'Bacteroidetes',
#    'Firmicutes',
#    'Proteobacteria',
#    'mouse model',
#    'misclassification'],
#   'SQ_TP': ['Bacterial microbiota AND IBD',
#    'Actinobacteria[Organism] AND IBD',
#    'Bateroidetes[Organism] AND IBD',
#    'Firmicutes[Organism] AND IBD',
#    'Proteobacteria[Organism] AND IBD'],
#   'SQ_FP': ['Actinobacteria[Organism] OR Bacteroidetes[Organism] OR Firmicutes[Organism] OR Proteobacteria[Organism] NOT IBD NOT (bacterial microbiota)',
#    'misclassification AND mouse model AND 16S rRNA gene'],
#   'SQ_R': ['bacterial microbiota NOT IBD',
#    'Proteobacteria[Organism] AND IBD NOT bacterial microbiota',
#    'IBD NOT bacterial microbiota',
#    'bacterial microbiota AND (Actinobacteria[Organism] OR Bacteroidetes[Organism] OR Firmicutes[Organism] OR Proteobacteria[Organism])'],
#   'PubMed_IDs_TP': ['38133321',
#    '38130639',
#    '38107848',
#    '38098663',
#    '38094217',
#    '38078655',
#    '38076401',
#    '38064817',
#    '38059748',
#    '38038385',
#    '38034829',
#    '37955225',
#    '37951044',
#    '38068850',
#    '37778980',
#    '37599322',
#    '37280117',
#    '37216124',
#    '37071621',
#    '37061125',
#    '36877446',
#    '36838425',
#    '36779280',
#    '36681226',
#    '36615467',
#    '36558391',
#    '38050911',
#    '38038385',
#    '38019873',
#    '38004116',
#    '37885171',
#    '37882738',
#    '37873878',
#    '37865178',
#    '37836692',
#    '37817517',
#    '37798913',
#    '37793274',
#    '37788400',
#    '38147604',
#    '38133321',
#    '38124090',
#    '38078655',
#    '38059748',
#    '38038385',
#    '38024237',
#    '38005855',
#    '38004116',
#    '37971273',
#    '37969979',
#    '37940667',
#    '37891621'],
#   'PubMed_IDs_FP': ['38155301',
#    '38154268',
#    '38154188',
#    '38155095',
#    '38154151',
#    '38153085',
#    '38153067',
#    '38152693',
#    '38152403',
#    '38152156',
#    '38150978',
#    '38150830',
#    '38150764'],
#   'PubMed_IDs_R': ['38154629',
#    '38155157',
#    '38154153',
#    '38153608',
#    '38152780',
#    '38151716',
#    '38151647',
#    '38151633',
#    '38151181',
#    '38151081',
#    '38151037',
#    '38150647',
#    '38150375',
#    '38147604',
#    '38124090',
#    '38024237',
#    '38005855',
#    '38004116',
#    '37971273',
#    '37969979',
#    '37940667',
#    '37891621',
#    '37817517',
#    '37778980',
#    '37771255',
#    '37710309',
#    '38155275',
#    '38155235',
#    '38154825',
#    '38154582',
#    '38154402',
#    '38154276',
#    '38151490',
#    '38149880',
#    '38149258',
#    '38148824',
#    '38147613',
#    '38147610',
#    '38147607',
#    '38154153',
#    '38151081',
#    '38150647',
#    '38149626',
#    '38147920',
#    '38146380',
#    '38146029',
#    '38145667',
#    '38145049',
#    '38144201',
#    '38141548',
#    '38141117',
#    '38140315']},
#  'https://dx.doi.org/10.3390/nu15071742': {'Pub Title': 'https://dx.doi.org/10.3390/nu15071742',
#   'Keywords': ['pediatric IBD',
#    "Crohn's disease",
#    'fecal microbiota transfer',
#    'exclusive enteral nutrition',
#    'microbial community composition',
#    '16S rRNA amplicon sequencing',
#    'immune regulation',
#    'disease progession in childhood-onset IBD',
#    'anti-TNF treatment',
#    'bile acid metabolism'],
#   'SQ_TP': ['pedriatic IBD AND fecal microbiota transfer',
#    'microbial community composition AND IBD',
#    'disease progression in childhood-onset'],
#   'SQ_FP': ['bile acid metabolism NOT IBD NOT fecal microbiota transfer',
#    '(exclusive enteral nurtition OR immune regulation) AND 16S rRNA amplicon sequencing'],
#   'SQ_R': ['immune regulation AND pediatric IBD NOT fecal microbiota transfer',
#    'disease progression in childhood-onset IBD NOT fecal microbiota transfer',
#    "Crohn's disease AND IBD",
#    'bile acid metabolism AND pedriatic IBD NOT fecal microbiota transfer NOT microbial community composition',
#    "Crohn's disease AND fecal microbiota transfer",
#    'microbial community compositon NOT IBD',
#    'IBD NOT microbial community composition'],
#   'PubMed_IDs_TP': ['38154276',
#    '38145046',
#    '38141180',
#    '38140362',
#    '38137947',
#    '38133321',
#    '38130639',
#    '38126747',
#    '38124090',
#    '38123972',
#    '38117272',
#    '38113381',
#    '38112525',
#    '38117343',
#    '20301446',
#    '38043102',
#    '38041679',
#    '37831662',
#    '20301790',
#    '23967498',
#    '37721284',
#    '37691042',
#    '37566027',
#    '37562882',
#    '37561984',
#    '37490682'],
#   'PubMed_IDs_FP': ['38154545',
#    '38153323',
#    '38152123',
#    '38151760',
#    '38151562',
#    '38149568',
#    '38147943',
#    '38146932',
#    '38145850',
#    '38143491',
#    '38142738',
#    '38141372',
#    '38139382',
#    '38097037',
#    '37956283',
#    '37915809',
#    '37844527',
#    '37732633',
#    '37695126',
#    '37688974',
#    '37581333',
#    '37148397',
#    '36905849',
#    '36677429',
#    '36159803',
#    '36017065'],
#   'PubMed_IDs_R': ['38137450',
#    '37968625',
#    '37789469',
#    '37780399',
#    '37769878',
#    '37697924',
#    '37396394',
#    '37330043',
#    '37311584',
#    '37279927',
#    '37160121',
#    '36857810',
#    '36694316',
#    '35520278',
#    '29126510',
#    '27748673',
#    '27478130',
#    '25844958',
#    '22772738',
#    '20839313',
#    '18725221',
#    '16454844',
#    '38154825',
#    '38154582',
#    '38154402',
#    '38149258',
#    '38148824',
#    '38147613',
#    '38147610',
#    '38147607',
#    '38147604',
#    '38147028',
#    '38144890',
#    '38144423',
#    '38144422',
#    '38133321',
#    '38044504',
#    '38029189',
#    '38018424',
#    '38016701',
#    '38004817',
#    '37981746',
#    '37935653',
#    '37769622',
#    '37681235',
#    '37646895',
#    '37602044',
#    '37446182',
#    '35574751',
#    '38155275',
#    '38155235',
#    '38154825',
#    '38154582',
#    '38154402',
#    '38151490',
#    '38149880',
#    '38149258',
#    '38148824',
#    '38147613',
#    '38147610',
#    '38147607',
#    '38147604']},
#  'https://dx.doi.org/10.3390/vetsci10020125': {'Pub Title': 'https://dx.doi.org/10.3390/vetsci10020125',
#   'Keywords': ['lymphoma',
#    'carcinoma',
#    'enteritis',
#    'ddPCR',
#    'canine intestinal tumours',
#    'miRNA',
#    'FFPE material',
#    'RNU6B'],
#   'SQ_TP': ['intestinal tumours AND IBD', 'canine intestinal tumours AND IBD'],
#   'SQ_FP': ['carcinoma AND lymphoma',
#    'enteritis NOT IBD NOT microbiota',
#    'FFPE material AND ddPCR',
#    'carcinoma AND (ddPCR OR miRNA)'],
#   'SQ_R': ['enteritis AND IBD', 'RNU6B AND IBD', 'miRNA profile AND IBD'],
#   'PubMed_IDs_TP': ['38142411',
#    '38134011',
#    '38002302',
#    '37942755',
#    '37895106',
#    '37882738',
#    '37881499',
#    '37867623',
#    '37863560',
#    '37849242',
#    '37831524',
#    '37815870',
#    '37797746',
#    '31239164',
#    '28993566',
#    '26173451',
#    '25487412',
#    '25323209',
#    '23953369',
#    '23216572',
#    '21962275'],
#   'PubMed_IDs_FP': ['38153289',
#    '38152104',
#    '38150195',
#    '38149563',
#    '38146364',
#    '38145769',
#    '38145398',
#    '38143675',
#    '38140723',
#    '38135580',
#    '38118434',
#    '38115646',
#    '38113273',
#    '38154741',
#    '38153949',
#    '38153712',
#    '38152848',
#    '38152810',
#    '38150367',
#    '38149277',
#    '38148903',
#    '38147796',
#    '38147526',
#    '38147237',
#    '38146385',
#    '38146101',
#    '37986562',
#    '37152023',
#    '36851429',
#    '35550815',
#    '33301768',
#    '33245553',
#    '33116639',
#    '31841714',
#    '30140723',
#    '30032824',
#    '29760807',
#    '29480566',
#    '29210102',
#    '38152335',
#    '38150987',
#    '38149567',
#    '38149560',
#    '38149558',
#    '38146079',
#    '38141378',
#    '38139051',
#    '38137560',
#    '38136338',
#    '38132438',
#    '38132395',
#    '38131468'],
#   'PubMed_IDs_R': ['38111141',
#    '38070932',
#    '38002268',
#    '38002251',
#    '37979446',
#    '37978573',
#    '37887947',
#    '37885336',
#    '37861390',
#    '37834076',
#    '37739064',
#    '37738641',
#    '37732778',
#    '19201770',
#    '38054256',
#    '37956249',
#    '37894314',
#    '37806279',
#    '37774039',
#    '37740761',
#    '37523213',
#    '37370191',
#    '37335372',
#    '37335014',
#    '37184747',
#    '37183784',
#    '37169818']},
#  'https://dx.doi.org/10.1038/s41590-023-01444-x': {'Pub Title': 'https://dx.doi.org/10.1038/s41590-023-01444-x',
#   'Keywords': ['kinetic proofreading model',
#    'linker activation of T cells',
#    'cell fate plasticity',
#    'Listeria infection',
#    'mouse model',
#    'autoimmunity',
#    'TCR ligand recognition'],
#   'SQ_TP': ['Listeria infection AND IBD AND microbiota'],
#   'SQ_FP': ['Listeria infection AND autoimmunity',
#    'cell fate plasticity AND (mouse model OR autoimmunity OR TCR ligand recognition)',
#    'kinetic proofreading model AND mouse model',
#    'TCR ligand recognition AND kinetic proofreading model'],
#   'SQ_R': ['cell fate plasticity AND IBD NOT Listeria infection',
#    'linker activation of T cells AND IBD',
#    'autoimmunity AND IBD OR linker activation of T cells AND IBD',
#    'TCR ligand recognition AND IBD'],
#   'PubMed_IDs_TP': [],
#   'PubMed_IDs_FP': ['38127070',
#    '38075415',
#    '38048804',
#    '37547023',
#    '37418594',
#    '36958172',
#    '36914891',
#    '36716589',
#    '36295036',
#    '35646766',
#    '35572995',
#    '35239442',
#    '35194174',
#    '38093367',
#    '38056453',
#    '37984072',
#    '37870650',
#    '37702214',
#    '37639113',
#    '37559721',
#    '37549271',
#    '37450380',
#    '37429840',
#    '37350155',
#    '37345845',
#    '37344645',
#    '37945821',
#    '36914891',
#    '35924922',
#    '31611699',
#    '29953453',
#    '28515297',
#    '25284152',
#    '20421471',
#    '16980618',
#    '12244312',
#    '11485738',
#    '24636916',
#    '16527543',
#    '11349650'],
#   'PubMed_IDs_R': ['33819486',
#    '31842491',
#    '24120477',
#    '38139373',
#    '38138587',
#    '38132266',
#    '38127803',
#    '38125685',
#    '38085149',
#    '38065857',
#    '38058270',
#    '38056916',
#    '38040100',
#    '38036883',
#    '38022524',
#    '38003220']},
#  'https://dx.doi.org/10.1136/gutjnl-2023-330362': {'Pub Title': 'https://dx.doi.org/10.1136/gutjnl-2023-330362',
#   'Keywords': ['Colorectal cancer',
#    'Helicobacter pylori',
#    'Apc-mutant mouse',
#    'immune and epithelial changes',
#    'tumorigenesis',
#    'antibiotics'],
#   'SQ_TP': ['Helicobacter pylori[Organism] AND colorectal cancer OR tumorigenesis AND IBD',
#    'Helicobacter pylori OR colorectal cancer AND IBD'],
#   'SQ_FP': ['NOT Helicobacter pylori[Organism] NOT IBD',
#    'Apc-mutant mouse AND antibiotics AND tumorigenesis'],
#   'SQ_R': ['immune and epithelial changes NOT Helicobacter pylori[Organism] NOT IBD',
#    'Helicobacter pylori[Organism] AND colorectal cancer'],
#   'PubMed_IDs_TP': ['38065263',
#    '38052229',
#    '37995573',
#    '37894314',
#    '37884500',
#    '37875976',
#    '37873142',
#    '37797746',
#    '37776619',
#    '37690027',
#    '37627960',
#    '37568640',
#    '37489647',
#    '38142411',
#    '38142126',
#    '38136300',
#    '38134011',
#    '38130742',
#    '38122957',
#    '38076713',
#    '38070244',
#    '38069495',
#    '38069446',
#    '38065263',
#    '38038385',
#    '38013230'],
#   'PubMed_IDs_FP': ['38154380',
#    '38153379',
#    '38153067',
#    '38152823',
#    '38151822',
#    '38148080',
#    '38147967',
#    '38145041',
#    '38144880',
#    '38143438',
#    '38140941',
#    '38140410',
#    '38139349',
#    '37015754',
#    '28584401',
#    '26320104',
#    '19855161'],
#   'PubMed_IDs_R': ['38153660',
#    '38141161',
#    '38139030',
#    '38137516',
#    '38127835',
#    '38122954',
#    '38117802',
#    '38116628',
#    '38103544',
#    '38102837',
#    '38102682',
#    '38096749',
#    '38081768',
#    '38148080',
#    '38126210',
#    '38035341',
#    '38018553',
#    '37989896',
#    '37964239',
#    '37918887',
#    '37899462',
#    '37861565',
#    '37849565',
#    '37843094',
#    '37754520',
#    '37754493']},
#  'https://dx.doi.org/10.3389/fimmu.2023.1157373': {'Pub Title': 'https://dx.doi.org/10.3389/fimmu.2023.1157373',
#   'Keywords': ['allergic inflammation',
#    'lipid mediators',
#    'eicosanoid family',
#    'RNA- and ATAC-sequencing',
#    'aryl hydrocarbon receptor',
#    'prostaglandin pathway',
#    'leukotriene pathway',
#    'mouse model',
#    'IgE',
#    'macrophages'],
#   'SQ_TP': ['allergic inflammation AND IBD AND microbiota'],
#   'SQ_FP': ['allergic inflammation AND (lipid mediators OR eicosanoid family) NOT IBD',
#    'RNA- and ATAC-sequencing AND allergic inflammation',
#    '(IgE OR macrophages) AND RNA- and ATAC-sequencing'],
#   'SQ_R': ['IgE AND IBD',
#    'lipid mediators AND IBD',
#    'aryl hydrocarbon receptor AND IBD',
#    'prostaglandin pathway AND IBD',
#    'leukotriene pathway AND IBD',
#    'macrophages AND IBD OR IgE AND IBD'],
#   'PubMed_IDs_TP': ['36323778',
#    '34891113',
#    '34684400',
#    '31352539',
#    '29754190',
#    '25567038',
#    '23755726'],
#   'PubMed_IDs_FP': ['37993706',
#    '37986167',
#    '37984747',
#    '37808700',
#    '37794280',
#    '37759432',
#    '37747743',
#    '37714152',
#    '37699080',
#    '37686715',
#    '37686250',
#    '37542852',
#    '37517103',
#    '37081886',
#    '37883975',
#    '37577382',
#    '37292857',
#    '37081886',
#    '36788807',
#    '34973294',
#    '34824203',
#    '34653365',
#    '34496250',
#    '34424946',
#    '33150420',
#    '32981416',
#    '31487549'],
#   'PubMed_IDs_R': ['37697336',
#    '37111022',
#    '37006985',
#    '36927749',
#    '36713411',
#    '35163137',
#    '34684400',
#    '34305428',
#    '33884251',
#    '33737936',
#    '33641182',
#    '33572978',
#    '33230079',
#    '38145852',
#    '38049007',
#    '38022496',
#    '37951044',
#    '37936449',
#    '37868958',
#    '37834076',
#    '37807005',
#    '37798913',
#    '37780399',
#    '37770568',
#    '37749611',
#    '37734910',
#    '38084103',
#    '38068838',
#    '38026194',
#    '37963876',
#    '37942478',
#    '37447212',
#    '37393618',
#    '37191444',
#    '37110329',
#    '37104918',
#    '36941128',
#    '36812782',
#    '36801011',
#    '37808771',
#    '37532297',
#    '37400966',
#    '36155972',
#    '36077306',
#    '35711544',
#    '35407469',
#    '35240193',
#    '35102343',
#    '34735907',
#    '34290057',
#    '33933753',
#    '33920650',
#    '35711544',
#    '35407469',
#    '32525764',
#    '29670469',
#    '29670278',
#    '28784429',
#    '24201219',
#    '22268894',
#    '18286646',
#    '15094864',
#    '12732366',
#    '7701249',
#    '8395694',
#    '38154276',
#    '38142236',
#    '38130639',
#    '38129886',
#    '38115636',
#    '38113752',
#    '38113649',
#    '38084103',
#    '38081366',
#    '38064817',
#    '38045056',
#    '38035969',
#    '38034382']},
#  'https://dx.doi.org/10.1186/s40168-023-01508-y': {'Pub Title': 'https://dx.doi.org/10.1186/s40168-023-01508-y',
#   'Keywords': ["Crohn's disease",
#    'murine models',
#    'ileo-colonic inflammation',
#    'segmented filamentous bacteria',
#    'dysbiotic microbial communities',
#    'tumor growth',
#    'iron availability',
#    'exclusive enteral nutrition'],
#   'SQ_TP': ['murine models AND IBD OR ileo-colonic inflammation AND IBD',
#    'ileo-colonic inflammation AND IBD',
#    'segmented filamentous bacteria AND IBD AND ileo-colonic inflammation',
#    'dysbiotic microbial communities AND IBD'],
#   'SQ_FP': ['segmented filamentous bacteria NOT IBD NOT dysbiotic microbial communities'],
#   'SQ_R': ['iron availability AND IBD NOT ileo-colonic inflammation',
#    'segmented filamentous bacteria AND dysbiotic microbial communities'],
#   'PubMed_IDs_TP': ['38149880',
#    '38140314',
#    '38138587',
#    '38124090',
#    '38113752',
#    '38113690',
#    '38112525',
#    '38110964',
#    '38110791',
#    '38098663',
#    '38096941',
#    '38084411',
#    '38084103',
#    '37004103',
#    '32674146',
#    '32014035',
#    '31450748',
#    '30574621',
#    '30414898',
#    '30388432',
#    '29290660',
#    '30845290',
#    '28079618',
#    '21549650',
#    '17466601',
#    '15319625',
#    '37004103',
#    '38096956',
#    '37909786',
#    '37377226',
#    '37335014',
#    '37246133',
#    '37052201',
#    '36958817',
#    '36821422',
#    '36806917',
#    '36735734',
#    '36499731',
#    '36280319',
#    '36270678'],
#   'PubMed_IDs_FP': ['38039966',
#    '38012160',
#    '37987749',
#    '37902602',
#    '37790571',
#    '37768824',
#    '37746224',
#    '37652351',
#    '37614301',
#    '37591835',
#    '37583515',
#    '37480326',
#    '37378323'],
#   'PubMed_IDs_R': ['38040695',
#    '37077923',
#    '36431320',
#    '35930123',
#    '35264972',
#    '35014851',
#    '34640466',
#    '34417961',
#    '34007138',
#    '33930197',
#    '33775573',
#    '33691543',
#    '33487265',
#    '26487367',
#    '26261005',
#    '25531553']},
#  'https://dx.doi.org/10.1038/s41467-023-36505-0': {'Pub Title': 'https://dx.doi.org/10.1038/s41467-023-36505-0',
#   'Keywords': ['SNAIL',
#    'transcritpional regulator',
#    'genetic models',
#    'tumorigenesis',
#    'cell cycle progression',
#    'senescence',
#    'animal model'],
#   'SQ_TP': ['animal model AND IBD AND intestinal bacteria'],
#   'SQ_FP': ['(cell cycle progression OR transcriptional regulator) AND genetic models NOT IBD',
#    'tumorigenesis AND animal model AND SNAIL'],
#   'SQ_R': ['SNAIL AND IBD',
#    '(transcriptional regulator OR  SNAIL) AND IBD',
#    'cell cycle progression AND IBD'],
#   'PubMed_IDs_TP': ['38140314',
#    '38073022',
#    '38068850',
#    '38024237',
#    '38004628',
#    '38004116',
#    '37971273',
#    '37968625',
#    '37898344',
#    '37865178',
#    '37842919',
#    '37836386',
#    '37817517'],
#   'PubMed_IDs_FP': ['38138971',
#    '38136364',
#    '38134679',
#    '38123360',
#    '38113141',
#    '38106540',
#    '38106208',
#    '38091997',
#    '38081944',
#    '38077447',
#    '38050190',
#    '38037549',
#    '38034564',
#    '36288851',
#    '35518787',
#    '34438248',
#    '34293352',
#    '34145034',
#    '33859739',
#    '33853342',
#    '33574674',
#    '33116416',
#    '33099085',
#    '32879054',
#    '32377731',
#    '32376245'],
#   'PubMed_IDs_R': ['37748815',
#    '35694541',
#    '34747049',
#    '34033998',
#    '33116416',
#    '33099085',
#    '30619271',
#    '28883695',
#    '28207769',
#    '27113480',
#    '23185435',
#    '22349829',
#    '21830269',
#    '38085149',
#    '38068838',
#    '38057834',
#    '38022496',
#    '38014192',
#    '38002251',
#    '37995775',
#    '37975549',
#    '37884352',
#    '37789469',
#    '37748815',
#    '37743134',
#    '37740761',
#    '37479963',
#    '36778265',
#    '36759174',
#    '36537314',
#    '34956195',
#    '34792672',
#    '34557865',
#    '34163519',
#    '33645438',
#    '33225975',
#    '32256204',
#    '32161943',
#    '31766534']},
#  'https://dx.doi.org/10.1038/s41590-023-01436-x': {'Pub Title': 'https://dx.doi.org/10.1038/s41590-023-01436-x',
#   'Keywords': ['pyrimidine starvation AND NOT IBD',
#    'pyrimidine synthesis inhibitor',
#    'autoimmunity',
#    'effector T cells',
#    'cell fate-determining checkpoint AND NOT IBD',
#    'leflunomide treatment',
#    'apoptosis',
#    'TCR signaling',
#    'mouse model',
#    'scRNA-sequencing'],
#   'SQ_TP': ['leflunomide treatment AND microbiome AND IBD'],
#   'SQ_FP': ['(effector T cells OR autoimmunity) AND IBD',
#    'pyrimidine synthesis inhibitor AND scRNA-sequencing NOT IBD',
#    '(effector T cells OR autoimmunity OR apoptosis OR TCR signaling) NOT IBD NOT microbiome',
#    'scRNA sequencing AND NOT IBD'],
#   'SQ_R': ['IBD AND (pyrimidine startvation OR pyrimidine synthesis inhibitor)',
#    'apoptosis AND IBD',
#    'TCR signaling AND IBD'],
#   'PubMed_IDs_TP': [],
#   'PubMed_IDs_FP': ['38139373',
#    '38138587',
#    '38132266',
#    '38127803',
#    '38125685',
#    '38085149',
#    '38065857',
#    '38058270',
#    '38056916',
#    '38040100',
#    '38036883',
#    '38022524',
#    '38003220',
#    '36857629',
#    '36222922',
#    '38155259',
#    '38155185',
#    '38155122',
#    '38155066',
#    '38154829',
#    '38154775',
#    '38154767',
#    '38154758',
#    '38154662',
#    '38154651',
#    '38154634',
#    '38154598',
#    '38154587',
#    '37983927',
#    '37943983',
#    '37753470',
#    '36922861',
#    '36817436',
#    '36782103',
#    '36462502',
#    '36353619',
#    '36311726',
#    '35328501',
#    '33359089',
#    '32915959',
#    '32753478'],
#   'PubMed_IDs_R': ['37907139',
#    '37880581',
#    '37870434',
#    '37827341',
#    '37512580',
#    '37475852',
#    '37475705',
#    '37178481',
#    '37000926',
#    '36764096',
#    '36745039',
#    '36603566',
#    '36232813',
#    '38113649',
#    '38070244',
#    '38066482',
#    '38065263',
#    '37995775',
#    '37976930',
#    '37968554',
#    '37925254',
#    '37907144',
#    '37901448',
#    '37899202',
#    '37873040',
#    '37859409',
#    '35273097',
#    '34226674',
#    '34120187',
#    '33381606',
#    '32929275',
#    '32117262',
#    '31533032',
#    '31324740',
#    '30951392',
#    '28124082',
#    '27062602',
#    '27011900',
#    '26965517']},
#  'https://dx.doi.org/10.1016/j.immuni.2023.04.010': {'Pub Title': 'https://dx.doi.org/10.1016/j.immuni.2023.04.010',
#   'Keywords': ['TCR repertoire',
#    'TCR avidity',
#    'recruitment',
#    'cross-reactivity',
#    'CD8+ T cells'],
#   'SQ_TP': ['IBD AND gut microbiome', 'TCR avidity AND IBD AND microbiome'],
#   'SQ_FP': ['cross-reactivity AND CD8+ T cells NOT IBD',
#    'recruitment AND cross-reactivity'],
#   'SQ_R': ['(TCR avidity OR TCR repertoire  OR recruitment) AND IBD',
#    'TCR repertoire AND IBD'],
#   'PubMed_IDs_TP': ['38151490',
#    '38145852',
#    '38140362',
#    '38138026',
#    '38133321',
#    '38130639',
#    '38128748',
#    '38124090',
#    '38123972',
#    '38113381',
#    '38110547',
#    '38102104',
#    '38099679'],
#   'PubMed_IDs_FP': ['38143762',
#    '37993788',
#    '37881436',
#    '37788543',
#    '37750245',
#    '37686141',
#    '37675596',
#    '37662941',
#    '37649599',
#    '37585383',
#    '37515456',
#    '37506745',
#    '37463649',
#    '38143762',
#    '38123740',
#    '38095049',
#    '38070782',
#    '38054523',
#    '38048805',
#    '38041026',
#    '38033005',
#    '38025484',
#    '38019237',
#    '37950790',
#    '37939049',
#    '37931352'],
#   'PubMed_IDs_R': ['38154825',
#    '38144422',
#    '38135729',
#    '38134391',
#    '38110881',
#    '38104569',
#    '38101846',
#    '38096956',
#    '38095246',
#    '38072359',
#    '38064817',
#    '38054256',
#    '38051719',
#    '37714427',
#    '36875135',
#    '36034703',
#    '35464463',
#    '35264446',
#    '33061522',
#    '32782948',
#    '32117262',
#    '32029881',
#    '31711184',
#    '31324740',
#    '30792246',
#    '30556140']},
#  'https://dx.doi.org/10.1016/j.jhep.2022.12.028': {'Pub Title': 'https://dx.doi.org/10.1016/j.jhep.2022.12.028',
#   'Keywords': ['liver regeneration',
#    'intestinal microbiome',
#    'lipidomics',
#    'mouse model',
#    'impaired lipogenesis',
#    'SCFA production',
#    'antibiotic treatment',
#    'hepatectomy',
#    'PCR',
#    '16S rRNA gene sequencing',
#    'hepatic membrane phospholipid bioynthesis AND NOT IBD'],
#   'SQ_TP': ['intestinal microbiome AND IBD'],
#   'SQ_FP': ['intestinal microbiome AND NOT IBD',
#    'lipodomics AND liver regeneration AND hepatectomy',
#    'PCR AND 16S rRNA sequencing',
#    'lipodomics NOT intestinal microbiome',
#    '(impaired lipogenesis OR SCFA production OR antibiotic treatment) NOT intestinal microbiome NOT IBD'],
#   'SQ_R': ['impaired lipogenesis AND IBD NOT intestinal microbiome',
#    'mouse model AND microbiome'],
#   'PubMed_IDs_TP': ['38154402',
#    '38151490',
#    '38141180',
#    '38140362',
#    '38137947',
#    '38133321',
#    '38128748',
#    '38124090',
#    '38123972',
#    '38113381',
#    '38110547',
#    '38102104',
#    '38096956'],
#   'PubMed_IDs_FP': ['38154402',
#    '38151490',
#    '38141180',
#    '38140362',
#    '38137947',
#    '38133321',
#    '38128748',
#    '38124090',
#    '38123972',
#    '38113381',
#    '38110547',
#    '38102104',
#    '38096956',
#    '38155301',
#    '38154893',
#    '38155157',
#    '38152373',
#    '38144289',
#    '38140133',
#    '38131677',
#    '38131029',
#    '38127820',
#    '38116185',
#    '38113702',
#    '38113523',
#    '38112268',
#    '38029177',
#    '36520866',
#    '35350651',
#    '30483182',
#    '26879888',
#    '25283058',
#    '25218302',
#    '25193136',
#    '25139561',
#    '25088698',
#    '25068410',
#    '24943800',
#    '24814048',
#    '38155229',
#    '38154995',
#    '38154961',
#    '38154809',
#    '38154746',
#    '38154739',
#    '38154658',
#    '38154648',
#    '38154518',
#    '38155204',
#    '38155176',
#    '38154153',
#    '38153906'],
#   'PubMed_IDs_R': ['38152983',
#    '38152693',
#    '38150908',
#    '38147734',
#    '38147649',
#    '38146368',
#    '38145850',
#    '38145758',
#    '38145695',
#    '38144811',
#    '38144564',
#    '38142919',
#    '38140300']},
#  'https://dx.doi.org/10.1016/j.chom.2022.09.011': {'Pub Title': 'https://dx.doi.org/10.1016/j.chom.2022.09.011',
#   'Keywords': ['mouse gut microbiota',
#    'anaerobic cultivation',
#    'synthetic community',
#    'gnotobiology',
#    'microbe-host interaction',
#    'Oligo-Mouse Microbiota',
#    'adaptive immune response AND NOT IBD',
#    'DSS-induced colitis AND NOT IBD',
#    'Clostridiales',
#    'Lactobacillaceae',
#    'Coriobacteriales'],
#   'SQ_TP': ['mouse gut microbiota AND IBD',
#    '(synthetic community OR anaerobic cultivation) AND IBD',
#    'microbe-host interaction AND IBD',
#    '(Clostridiales[Organism] OR Lactobacillaceae[Organism] OR Coriobacteriales[Organism]) AND IBD'],
#   'SQ_FP': ['anaerobic cultivation NOT mouse gut microbiota NOT gnotobiology',
#    '(Clostridiales[Organism] OR Lactobacillaceae[Organism] OR Coriobacteriales[Organism]) NOT IBD NOT microbe-host interaction NOT gut microbiota'],
#   'SQ_R': ['mouse gut microbiota NOT microbe-host interaction',
#    '(microbiome-host interaction OR gnotobiology) NOT gut microbiota'],
#   'PubMed_IDs_TP': ['38126747',
#    '38124090',
#    '38112525',
#    '38098663',
#    '38096941',
#    '38073022',
#    '38068850',
#    '38068838',
#    '38064817',
#    '38059748',
#    '38035969',
#    '38033588',
#    '38026194',
#    '37630561',
#    '37367886',
#    '35955473',
#    '35140783',
#    '34662575',
#    '31726738',
#    '30990326',
#    '29033923',
#    '27252786',
#    '26907552',
#    '25179909',
#    '24053649',
#    '18419142',
#    '38110547',
#    '37998910',
#    '37950021',
#    '37932270',
#    '37909786',
#    '37873588',
#    '37842912',
#    '37805634',
#    '37702510',
#    '37546537',
#    '37526424',
#    '37512580',
#    '37476672',
#    '38050911',
#    '38019873',
#    '37916431',
#    '37885171',
#    '37882738',
#    '37873878',
#    '37798913',
#    '37793274',
#    '37788400',
#    '37646895',
#    '37577378',
#    '37549964',
#    '37481231'],
#   'PubMed_IDs_FP': ['38151924',
#    '38147780',
#    '38146449',
#    '38145708',
#    '38138045',
#    '38128981',
#    '38128305',
#    '38114556',
#    '38111817',
#    '38104970',
#    '38104821',
#    '38100018',
#    '38095693',
#    '38153527',
#    '38150830',
#    '38147830',
#    '38146044',
#    '38143859',
#    '38140671',
#    '38140378',
#    '38138183',
#    '38138067',
#    '38137291',
#    '38136611',
#    '38133199',
#    '38132109'],
#   'PubMed_IDs_R': ['38154262',
#    '38153838',
#    '38153260',
#    '38152989',
#    '38152983',
#    '38152693',
#    '38152123',
#    '38151562',
#    '38151081',
#    '38150707',
#    '38150643',
#    '38150235',
#    '38149319',
#    '38111640',
#    '38022683',
#    '38003758',
#    '37985877',
#    '37902602',
#    '37888992',
#    '37873282',
#    '37872770',
#    '37869650',
#    '37867968',
#    '37799720',
#    '37767872',
#    '37730461']},
#  'https://dx.doi.org/10.3389/fimmu.2022.901194': {'Pub Title': 'https://dx.doi.org/10.3389/fimmu.2022.901194',
#   'Keywords': ['Aryl Hydrocarbon Receptor',
#    'Allergic Airway Inflammation',
#    'CYP1 activity',
#    'mouse model',
#    'immunoregulation',
#    'skin and intestinal inflammatory disorders AND IBD',
#    'circadian clock genes AND NOT IBD',
#    'RNA extraction',
#    'PCR'],
#   'SQ_TP': ['intestinal inflammation AND (IBD OR gut microbiome)'],
#   'SQ_FP': ['mouse model AND immunoregulation NOT IBD NOT microbiome',
#    'PCR AND RNA extraction AND CYP1 activity',
#    'Allergic Airway Inflammation NOT IBD',
#    'circadian clock genes AND RNA extraction AND mouse model'],
#   'SQ_R': ['CYP1 activity AND IBD',
#    'microbe-host interaction AND (allergic airway inflammation OR aryl hydrocarbon receptor)'],
#   'PubMed_IDs_TP': ['38147028',
#    '38146368',
#    '38145046',
#    '38144564',
#    '38144163',
#    '38140362',
#    '38139027',
#    '38138587',
#    '38137946',
#    '38137870',
#    '38137644',
#    '38137365',
#    '38137214'],
#   'PubMed_IDs_FP': ['38137420',
#    '38117752',
#    '38111045',
#    '38072921',
#    '38035330',
#    '38034794',
#    '38026962',
#    '38013040',
#    '37984469',
#    '37956491',
#    '37954597',
#    '37952487',
#    '37940081',
#    '38154627',
#    '38154470',
#    '38151732',
#    '38149746',
#    '38148520',
#    '38148093',
#    '38144091',
#    '38142785',
#    '38142780',
#    '38135684',
#    '38134932',
#    '38125474',
#    '38125351',
#    '37788001',
#    '37576540',
#    '33528793',
#    '32360784',
#    '31070671',
#    '27688755',
#    '21254899',
#    '12606319'],
#   'PubMed_IDs_R': ['37794486',
#    '37577144',
#    '37293566',
#    '37191444',
#    '35804761',
#    '35367341',
#    '35295917',
#    '35210367',
#    '34869783',
#    '34818549',
#    '34722615',
#    '34675385',
#    '34646390']},
#  'https://dx.doi.org/10.1016/j.molmet.2022.101628': {'Pub Title': 'https://dx.doi.org/10.1016/j.molmet.2022.101628',
#   'Keywords': ['Circadian rhythm',
#    'SCN',
#    'Shift work',
#    'SCFA',
#    'bile acids',
#    'intestinal clock AND NOT IBD',
#    'body weight changes',
#    'mouse model',
#    'qPCR',
#    '16S rRNA gene amplicon sequencing'],
#   'SQ_TP': ['bile acids AND microbiome AND IBD'],
#   'SQ_FP': ['qPCR AND 16S rRNA gene amplicon sequencing',
#    'Circadian rhythm AND Shift work AND SCFA AND body weight changes',
#    'Circadian rhythm AND bile acids NOT IBD NOT microbiome',
#    'SCN AND SCFA'],
#   'SQ_R': ['bile acids AND IBD', 'body weight changes AND IBD'],
#   'PubMed_IDs_TP': ['38052229',
#    '38044504',
#    '37933950',
#    '37818653',
#    '37780399',
#    '37739064',
#    '37580334',
#    '37515676',
#    '37508557',
#    '37491256',
#    '37487380',
#    '37464092',
#    '37344396'],
#   'PubMed_IDs_FP': ['38098883',
#    '38098672',
#    '38088308',
#    '38053218',
#    '38049822',
#    '38029116',
#    '38007133',
#    '38004740',
#    '38003760',
#    '37806429',
#    '37779711',
#    '37768925',
#    '37764116',
#    '36334897',
#    '37647292',
#    '37209828',
#    '36744213',
#    '36602574',
#    '36421923',
#    '36264144',
#    '35878927',
#    '35451003',
#    '35202886',
#    '35187990',
#    '35176510',
#    '34302623',
#    '34279029',
#    '36334897'],
#   'PubMed_IDs_R': ['38052229',
#    '38044504',
#    '38036883',
#    '37980492',
#    '37933950',
#    '37876938',
#    '37818653',
#    '37780399',
#    '37739064',
#    '37580334',
#    '37519211',
#    '37515676',
#    '37508557',
#    '38123053',
#    '38075867',
#    '38069197',
#    '37976930',
#    '37922567',
#    '37919307',
#    '37891901',
#    '37864000',
#    '37848840',
#    '37803644',
#    '37779327',
#    '37704122',
#    '37516511']},
#  'https://dx.doi.org/10.1111/jdv.17911': {'Pub Title': 'https://dx.doi.org/10.1111/jdv.17911',
#   'Keywords': ['Microbial dysbiosis',
#    'atopic dermatitis',
#    'skin microbiome communities',
#    'mouse model',
#    'Staphylococci',
#    'Lachnospiraceae',
#    'Muribaculaceae',
#    'calciportiol',
#    'oxazolone',
#    'IgE induction',
#    'cytokines'],
#   'SQ_TP': ['Microbial dysbiosis AND IBD',
#    'Staphylococci[Organism] AND IBD',
#    'microbiome communities AND IBD'],
#   'SQ_FP': ['atopic dermatitis NOT IBD NOT bacterial micriobiome',
#    '(calcipotriol OR oxazolone) AND cytokines AND (IgE induction OR atopic dermatitis)',
#    'IgE induction AND cytokines'],
#   'SQ_R': ['IgE induction AND IBD NOT microbiome',
#    'cytokines AND IBD NOT microbiome',
#    'Microbial dysbiosis AND microbiome communities NOT IBD',
#    'microbiome AND atopic dermatitis NOT IBD'],
#   'PubMed_IDs_TP': ['38145046',
#    '38107848',
#    '38096956',
#    '38033588',
#    '38025434',
#    '38021365',
#    '38016379',
#    '38009836',
#    '38008696',
#    '38004817',
#    '37998910',
#    '37996842',
#    '37946238',
#    '27239107',
#    '22179208',
#    '19897974',
#    '38113381',
#    '38102104',
#    '38094217',
#    '38065263',
#    '38033588',
#    '38022505',
#    '38019873',
#    '37998910',
#    '37949638',
#    '37946238',
#    '37940667',
#    '37917397',
#    '37901813'],
#   'PubMed_IDs_FP': ['38154665',
#    '38152869',
#    '38151921',
#    '38151728',
#    '38151479',
#    '38151335',
#    '38151270',
#    '38150707',
#    '38150167',
#    '38149974',
#    '38149911',
#    '38149692',
#    '38149402',
#    '37996010',
#    '37889696',
#    '37832861',
#    '37813655',
#    '37783432',
#    '37741129',
#    '37731552',
#    '37721853',
#    '37512164',
#    '37417726',
#    '37107248',
#    '37029953',
#    '36983043',
#    '38142953',
#    '38125474',
#    '38094094',
#    '38012745',
#    '37855043',
#    '37794629',
#    '37788409',
#    '37741129',
#    '37676892',
#    '37524663',
#    '37485534',
#    '37439364',
#    '37376217'],
#   'PubMed_IDs_R': ['33737936',
#    '28631311',
#    '27604348',
#    '26181108',
#    '22293328',
#    '16547276',
#    '38149258',
#    '38142236',
#    '38138587',
#    '38137450',
#    '38136191',
#    '38115636',
#    '38113649',
#    '38106709',
#    '38106420',
#    '38085149',
#    '38084103',
#    '38069197',
#    '38066482',
#    '38143595',
#    '38129978',
#    '38113619',
#    '38110878',
#    '38108398',
#    '38104979',
#    '38098667',
#    '38088975',
#    '38088183',
#    '38088063',
#    '38084923',
#    '38077090',
#    '38075222',
#    '38150707',
#    '38138183',
#    '38132113',
#    '38118418',
#    '38093985',
#    '38054607',
#    '38053996',
#    '38052685',
#    '38045611',
#    '38040916',
#    '38035082',
#    '38029543',
#    '38027278']},
#  'https://dx.doi.org/10.1080/19490976.2022.2107386': {'Pub Title': 'https://dx.doi.org/10.1080/19490976.2022.2107386',
#   'Keywords': ['gut microbiota',
#    'host immunity',
#    'model organisms',
#    'causality',
#    'host-microbe interactions',
#    'metabolite profiling',
#    'gene modifications',
#    'surgically induced models',
#    'SCFA',
#    'gnotobiology',
#    'immunity regulation'],
#   'SQ_TP': ['gut microbiota AND IBD', 'host-microbe interactions AND IBD'],
#   'SQ_FP': ['host immunity AND causality NOT IBD',
#    'model organism AND causality AND SCFA NOT IBD NOT microbiome',
#    'gene modifications AND immunity regulation AND causality NOT microbiome NOT IBD'],
#   'SQ_R': ['SCFA AND IBD',
#    'metabolite profiling AND IBD',
#    'gnotobiology AND IBD NOT microbiome'],
#   'PubMed_IDs_TP': ['38154276',
#    '38145046',
#    '38140362',
#    '38133321',
#    '38130639',
#    '38128748',
#    '38126747',
#    '38124090',
#    '38123972',
#    '38113381',
#    '38112525',
#    '38110547',
#    '38107848',
#    '38124090',
#    '38110547',
#    '37998910',
#    '37950021',
#    '37932270',
#    '37909786',
#    '37873588',
#    '37842912',
#    '37805634',
#    '37702510',
#    '37526424',
#    '37512580',
#    '37476672'],
#   'PubMed_IDs_FP': ['38154068',
#    '38152968',
#    '38149246',
#    '38149009',
#    '38149007',
#    '38148115',
#    '38147552',
#    '38143766',
#    '38143750',
#    '38140875',
#    '38140685',
#    '38140669',
#    '38140654',
#    '33208449',
#    '28241897',
#    '27838381',
#    '23401169',
#    '21178092',
#    '17217564',
#    '17092369',
#    '15284380',
#    '14512034',
#    '10052805',
#    '8672754',
#    '38145548',
#    '38136994',
#    '38112999',
#    '38112997',
#    '38097986',
#    '38097948',
#    '38073441',
#    '38069131',
#    '38068937',
#    '38065948',
#    '38063205',
#    '38062834',
#    '38057752'],
#   'PubMed_IDs_R': ['38138026',
#    '38044504',
#    '38037542',
#    '37892541',
#    '37876938',
#    '37807005',
#    '37789460',
#    '37741962',
#    '37736865',
#    '37662255',
#    '37630561',
#    '37558022',
#    '37479833',
#    '37849974',
#    '37813075',
#    '37789469',
#    '37774039',
#    '37630561',
#    '37577378',
#    '37536268',
#    '37527838',
#    '37512580',
#    '37504267',
#    '37475705',
#    '37346749',
#    '37298868',
#    '26218526',
#    '21545711',
#    '19271150']}}

# %% [markdown]
# #### Option 2: This one only writes the PubMed id's in the dictionary and not the used queries

# %% [markdown]
# def dict_to_pubmed_id_reduced(input_dict):
#     # Initialize a new dictionary to store the results
#     result_dict = {}
#
#     # Iterate over each publication entry in the input dictionary
#     for pub_title, pub_data in input_dict.items():
#         # Initialize a dictionary to store PubMed IDs and Pub Title
#         pub_result = {'Pub Title': pub_title}
#
#         # Initialize empty lists for PubMed IDs for SQ_TP, SQ_FP, and SQ_R
#         pub_result['PubMed_IDs_TP'] = []
#         pub_result['PubMed_IDs_FP'] = []
#         pub_result['PubMed_IDs_R'] = []
#
#         # Extract elements from SQ_TP, SQ_FP, and SQ_R lists and search PubMed for IDs
#         for sq_tp_element in pub_data['SQ_TP']:
#             pub_result['PubMed_IDs_TP'].extend(search_pubmed_for_ids(sq_tp_element))
#
#         for sq_fp_element in pub_data['SQ_FP']:
#             pub_result['PubMed_IDs_FP'].extend(search_pubmed_for_ids(sq_fp_element))
#
#         for sq_r_element in pub_data['SQ_R']:
#             pub_result['PubMed_IDs_R'].extend(search_pubmed_for_ids(sq_r_element))
#
#         # Add the modified publication data to the result dictionary
#         result_dict[pub_title] = pub_result
#
#     return result_dict

# %% [markdown]
# result2_dict = dict_to_pubmed_id_reduced(keywords_dict)
# result2_dict

# %% [markdown]
# #### Step 4: export dictionaries as xml and json files

# %%
import json
import xml.etree.ElementTree as ET

# %%
# Convert to JSON
json_data = json.dumps(result_dict, indent=2)

# Save to a JSON file
with open("output_ID2.json", "w") as json_file:
    json_file.write(json_data)

# %%
# Convert to XML
def save_result_dict_to_xml(result_dict, xml_file_path):
    # Create the root element
    root = ET.Element("result_dict")

    # Iterate over each publication entry in the result dictionary
    for pub_title, pub_result in result_dict.items():
        entry = ET.SubElement(root, "entry")
        ET.SubElement(entry, "PubTitle").text = pub_result['Pub Title']

        # Add PubMed IDs for SQ_TP
        sq_tp = ET.SubElement(entry, "PubMed_IDs_TP")
        for pubmed_id in pub_result['PubMed_IDs_TP']:
            ET.SubElement(sq_tp, "PubMed_ID").text = pubmed_id

        # Add PubMed IDs for SQ_FP
        sq_fp = ET.SubElement(entry, "PubMed_IDs_FP")
        for pubmed_id in pub_result['PubMed_IDs_FP']:
            ET.SubElement(sq_fp, "PubMed_ID").text = pubmed_id

        # Add PubMed IDs for SQ_R
        sq_r = ET.SubElement(entry, "PubMed_IDs_R")
        for pubmed_id in pub_result['PubMed_IDs_R']:
            ET.SubElement(sq_r, "PubMed_ID").text = pubmed_id

    # Create the XML tree
    xml_tree = ET.ElementTree(root)

    # Save the XML tree to the specified file
    xml_tree.write(xml_file_path)

# %%
# Specify the path for the XML file
xml_file_path = "output.xml"

# Save the result_dict to an XML file
save_result_dict_to_xml(result_dict, xml_file_path)

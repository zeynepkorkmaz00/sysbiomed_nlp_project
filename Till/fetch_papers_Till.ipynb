# %% [markdown]
# ## Task Force A: Fetching PubMed ID's from queries

# %%
from Bio import Entrez
import csv

# %% [markdown]
# ### Step 1: Make function to search for papers and return their PubMED IDs

# %%
def search_pubmed_for_ids(query, max_results=13):
    Entrez.email = "zeynep.korkmaz@tum.de"  # Set email address

    handle = Entrez.esearch(db="pubmed", term=query, retmax=max_results)
    record = Entrez.read(handle)
    handle.close()

    return record["IdList"]

# %%
# Example query
search_pubmed_for_ids("Helicobacter[Organsim] NOT IBD NOT intestinal microbes")
# Out:
# ['38179804', '38179545', '38177692', '38176660', '38176008', '38175580', '38173317', '38173305', '38172074', '38171342', '38171101', '38169417', '38167662', '38167394', '38166953', '38165856', '38164932', '38162866', '38162864', '38162071', '38162007', '38161000', '38160708']

# %% [markdown]
# ### Step 2: Create the keyword and query list from the csv file

# %%
def read_keywords_from_csv(csv_file):
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)

        keywords_dict = {}
        
        current_pub_title = None
        current_keywords = []
        current_sq_tp = []
        current_sq_fp = []
        current_sq_r = []

        for row in reader:
            
            # Remove trailing commas from each element in the row
            row = [item.strip(', ') for item in row]
            
            if row and not row[0].isdigit():  # Skip numeric rows
                if row[0] == "Pub Title":
                    if current_pub_title:
                        # create for every title/DOI keys
                        keywords_dict[current_pub_title] = {
                            "Pub Title": current_pub_title,
                            "Keywords": current_keywords,
                            "SQ_TP": current_sq_tp,
                            "SQ_FP": current_sq_fp,
                            "SQ_R": current_sq_r
                        }
                    current_pub_title = row[1]
                    current_keywords = []
                    current_sq_tp = []
                    current_sq_fp = []
                    current_sq_r = []
                    # add values to list of the different keys and check for empty entries
                elif row[0] == "Keywords":
                    current_keywords.extend(item for item in row[1:] if item)
                elif row[0] == "SQ_TP":
                    current_sq_tp.extend(item for item in row[1:] if item)
                elif row[0] == "SQ_FP":
                    current_sq_fp.extend(item for item in row[1:] if item)
                elif row[0] == "SQ_R":
                    current_sq_r.extend(item for item in row[1:] if item)

        # Add the last entry
        if current_pub_title:
            keywords_dict[current_pub_title] = {
                "Pub Title": current_pub_title,
                "Keywords": current_keywords,
                "SQ_TP": current_sq_tp,
                "SQ_FP": current_sq_fp,
                "SQ_R": current_sq_r
            }

    return keywords_dict

# %% [markdown]
# ##### How the dictionary looks:

# %%
# path to csv file 
input_csv = "/Users/tillohlendorf/Documents/MBT/Module/Systems BioMedicine/NLP/TFA_repo/sysbiomed_nlp_project/Keywords/keywords_Till.csv"

# %%
# create dictionary from csv
keywords_dict = read_keywords_from_csv(input_csv)

# %%
keywords_dict
# Out:
# {'Mitochondrial impairment drives intestinal stem cell transition into dysfunctional Paneth cells predicting Crohn’s disease recurrence.': {'Pub Title': 'Mitochondrial impairment drives intestinal stem cell transition into dysfunctional Paneth cells predicting Crohn’s disease recurrence.',
#   'Keywords': ['paneth cells',
#    "Crohn's disease",
#    'LGR5+ intestinal stemm cells',
#    'organoids',
#    'TNFΔARE mice',
#    'ISC morphological appearance',
#    'PC morphological appearance',
#    'mitochondrial dysfunction',
#    'ileal tissue samples',
#    'PC granularity',
#    'surgical resection',
#    'CD recurrence',
#    'CD',
#    'PC',
#    'intestinal stemm cells'],
#   'SQ_TP': ["(PC or paneth cells) AND (CD or Crohn's disease) AND ISC morphological appearance",
#    "(LGR5+) AND (CD or Crohn's disease)",
#    "((PC or paneth cells) granularity) AND (CD or Crohn's disease)",
#    "(CD or Crohn's disease) AND mitochondrial dysfunction"],
#   'SQ_FP': ["(PC or paneth cells) NOT ((CD or Crohn's disease) OR IBD)",
#    "organoids NOT ((CD or Crohn's disease) OR IBD)",
#    "surgical resection NOT ((CD or Crohn's disease) OR IBD)"],
#   'SQ_R': ["((PC or paneth cells) OR (CD or Crohn's disease)) AND organoids",
#    "((PC or paneth cells) OR (CD or Crohn's disease)) AND TNFΔARE mice",
#    "(PC or paneth cells) AND (CD or Crohn's disease)"]},
#  'The Spatial Heterogeneity of the Gut Limits Predation and Fosters Coexistence of Bacteria and Bacteriophages': {'Pub Title': 'The Spatial Heterogeneity of the Gut Limits Predation and Fosters Coexistence of Bacteria and Bacteriophages',
#   'Keywords': ['phage therapy',
#    'Mt1B1 E. coli',
#    'OMM12 mouse model',
#    'phage resistance',
#    'spatial refuges',
#    'proliferation threshold',
#    'phage bacteria coexistence',
#    'off-target phage amplification',
#    'spatial heterogeneity',
#    'coexistance',
#    'bacteriophages',
#    'gut'],
#   'SQ_TP': ['phage therapy AND spatial refuges AND gut'],
#   'SQ_FP': ['Mt1B1 E. coli AND proliferation threshold NOT gut',
#    'OMM12 mouse model NOT gut'],
#   'SQ_R': ['phage bacteria coexistence AND phage therapy',
#    'phage therapy AND proliferation threshold AND gut']},
#  "Integrated microbiota and metabolite profiles link Crohn's disease to sulfur metabolism": {'Pub Title': "Integrated microbiota and metabolite profiles link Crohn's disease to sulfur metabolism",
#   'Keywords': ['HSCT',
#    'autologous hematopoetic stem cell transplantation',
#    "Crohn's disease",
#    'community richness',
#    'community diversity',
#    'gnotobiotic humanized mice',
#    'multi-omics',
#    'metabolites',
#    'sulfur metabolism',
#    'Desulfovibrio',
#    'sulfate-reducing bacteria',
#    'Bilophila',
#    'Bacteriodes fragilis',
#    'functional modules',
#    'transition metals transport systems',
#    'hematopoetic stem cell transplantation'],
#   'SQ_TP': ['HSCT AND sulfur metabolism AND CD',
#    'multi-omics AND CD AND Desulfovibrio',
#    'HSCT AND sulfate-reducing bacteria AND CD AND transition metals transport systems'],
#   'SQ_FP': ['multi-omics NOT (CD OR IBD)',
#    'gnotobiotic humanized mice AND multi-omics NOT (CD or IBD)'],
#   'SQ_R': ['Desulfovibrio AND sulfur metabolism AND CD',
#    'multi-omics AND CD AND Desulfovibrio',
#    'community richness AND HSCT AND CD']},
#  'MCL-1 gains occur with high frequency in lung adenocarcinoma and can be targeted therapeutically': {'Pub Title': 'MCL-1 gains occur with high frequency in lung adenocarcinoma and can be targeted therapeutically',
#   'Keywords': ['MCL-1',
#    'lung adenocarcinoma',
#    'NSCLC',
#    'murine tumor model',
#    'rational drug target',
#    'TP53',
#    'oncogene addiction',
#    'cancer cell lines',
#    'organoids',
#    'clonal evolution',
#    'drug target',
#    'cancer'],
#   'SQ_TP': ['MCL-1 AND NSCLC AND drug target',
#    'murine tumor model AND MCL-1 AND NSCLC',
#    'MCL-1  AND murine tumor model AND oncogene addiction'],
#   'SQ_FP': ['TP53 NOT (NSCLC OR lung adenocarcinoma OR cancer)',
#    'TP53 NOT (cancer OR IBD)'],
#   'SQ_R': ['(NSCLC OR MCL-1) AND (microbiome)']},
#  'MS-Based in Situ Proteomics Reveals AMPylation of Host Proteins during Bacterial Infection': {'Pub Title': 'MS-Based in Situ Proteomics Reveals AMPylation of Host Proteins during Bacterial Infection',
#   'Keywords': ['AMPylation',
#    'adenylylation',
#    'RHO GTPases',
#    'Fic',
#    'VopS',
#    'infection',
#    'proteomics',
#    'in situ proteomics',
#    'pro-N6pA',
#    'effector proteins',
#    'Vibrio parahaemolyticus'],
#   'SQ_TP': ['(AMPylation or adenylylation) AND infection AND proteomics',
#    '(Fic or VopS) AND AMPylation AND infection',
#    'pro-N6pA AND in situ proteomics AND infection AND (AMPylation or adenylylation)'],
#   'SQ_FP': ['proteomics NOT (infection OR IBD)',
#    'Vibrio parahaemolyticus NOT (infection OR IBD)',
#    'RHO GTPases NOT (infection OR IBD)'],
#   'SQ_R': ['infection AND effector proteins',
#    'pro-N6pA AND in situ proteomics AND infection']},
#  'Arrhythmic Gut Microbiome Signatures Predict Risk of Type 2 Diabetes': {'Pub Title': 'Arrhythmic Gut Microbiome Signatures Predict Risk of Type 2 Diabetes',
#   'Keywords': ['human intestinal microbiota',
#    'population-based cohorts',
#    'circadian rythms',
#    'diurnal oscillations',
#    'type 2 diabetes',
#    'metagenomics',
#    'amplicon sequencing',
#    'obesity',
#    'machine learning',
#    'prediction',
#    'microbiome',
#    'gut'],
#   'SQ_TP': ['(circadian rythms OR  diurnal oscillations) AND type 2 diabetes AND (microbiome OR metagenomics) AND (prediction OR machine learning)'],
#   'SQ_FP': ['type 2 diabetes NOT microbiome',
#    'circadian rythms NOT microbiome',
#    'metagenomics NOT microbiome'],
#   'SQ_R': ['type 2 diabetes AND microbiome',
#    'metagenomics AND (circadian rythms OR  diurnal oscillations) AND gut',
#    '(human intestinal microbiota OR gut OR microbiome) AND prediction AND type 2 diabetes']},
#  'The CMV-Specific CD8+ T Cell Response Is Dominated by Supra-Public Clonotypes with High Generation Probabilities': {'Pub Title': 'The CMV-Specific CD8+ T Cell Response Is Dominated by Supra-Public Clonotypes with High Generation Probabilities',
#   'Keywords': ['memory inflation',
#    'clonotypes',
#    'generation probability',
#    'T cell response',
#    'TCR',
#    'convergent recombination',
#    'TCR repertoire',
#    'cytomegalovirus',
#    'mouse model',
#    'CMV',
#    'public clonotypes'],
#   'SQ_TP': ['public clonotype AND CMV AND (T cell response OR TCR) AND mouse model'],
#   'SQ_FP': ['CMV NOT (clonotype OR IBD)', 'CMV NOT (TCR OR IBD)'],
#   'SQ_R': ['public clonotype AND CMV AND T cell response',
#    'clonotype AND (TCR OR T cell response)']},
#  'Reverse TCR repertoire evolution toward dominant low-affinity clones during chronic CMV infection': {'Pub Title': 'Reverse TCR repertoire evolution toward dominant low-affinity clones during chronic CMV infection',
#   'Keywords': ['T cell immunity',
#    'affnity maturation',
#    'clonal selection',
#    'TCR',
#    'T cell response',
#    'cytomegalovirus',
#    'chronic infection',
#    'senescence',
#    'immunopathology',
#    'immunotherapy',
#    'CMV'],
#   'SQ_TP': ['CMV AND affinity maturation AND low-affinity AND (TCR OR T cell response)'],
#   'SQ_FP': ['CMV NOT ((TCR OR T cell response) OR IBD)'],
#   'SQ_R': ['infection AND affinity maturation AND low-affinity',
#    'infection AND clonal selection AND low-affinity']},
#  'The gut bacterium Extibacter muris produces secondary bile acids and influences liver physiology in gnotobiotic mice': {'Pub Title': 'The gut bacterium Extibacter muris produces secondary bile acids and influences liver physiology in gnotobiotic mice',
#   'Keywords': ['lipids',
#    'bile acids',
#    'gut microbiota',
#    'synthetic community',
#    'Oligo-MM12',
#    'Extibacter muris',
#    'gut-liver axis',
#    '7α-dehydroxylation',
#    'gnotobiotic mouse model',
#    'hepatic response',
#    'liver physiology',
#    'proteomics',
#    'mouse model'],
#   'SQ_TP': ['lipids AND Extibacter muris AND bile acids AND mouse model AND proteomics'],
#   'SQ_FP': ['bile acids NOT (gut microbiota OR IBD)'],
#   'SQ_R': ['bile acids AND gut-liver axis AND Extibacter muris',
#    'lipids AND gut-liver axis AND Extibacter muris',
#    'lipids AND gut-liver axis AND gut microbiota']},
#  'A collection of bacterial isolates from the pig intestine reveals functional and taxonomic diversity': {'Pub Title': 'A collection of bacterial isolates from the pig intestine reveals functional and taxonomic diversity',
#   'Keywords': ['pig microbiota',
#    'pig gut',
#    '16S rRNA',
#    'metagenomics',
#    'fucosyltransferase',
#    'Clostridium porci',
#    'sactipeptides',
#    'bile acids',
#    'Bullifex porci',
#    'MALDI',
#    'proteomes'],
#   'SQ_TP': ['pig microbiota AND metagenomics AND MALDI'],
#   'SQ_FP': ['bile acids NOT (pigs OR IBD)'],
#   'SQ_R': ['pig microbiota AND metagenomics AND proteomes',
#    'pig gut AND 16S rRNA']},
#  'A protease-activated, near-infrared fluorescent probe for early endoscopic detection of premalignant gastrointestinal lesions': {'Pub Title': 'A protease-activated, near-infrared fluorescent probe for early endoscopic detection of premalignant gastrointestinal lesions',
#   'Keywords': ['Early detection',
#    'flourescence',
#    'endoscopy',
#    'activity-based probe',
#    'high-risk patients',
#    'gastrointestinal lesions',
#    'dysplasia',
#    'inflammatory bowel disease',
#    'adenoma detection rate',
#    'APC mouse model',
#    'cathepsin-activated probe'],
#   'SQ_TP': ['flourescent probe AND gastrointestinal lesions AND early detection'],
#   'SQ_FP': ['endoscopy NOT IBD'],
#   'SQ_R': ['gastrointestinal lesions AND early detection',
#    'gastrointestinal lesions AND activity-based probe']},
#  'Bile acids drive the newborn’s gut microbiota maturation': {'Pub Title': 'Bile acids drive the newborn’s gut microbiota maturation',
#   'Keywords': ['maternal microbiome',
#    'liver maturation',
#    'newborn',
#    'gut microbiota',
#    'microbiota maturation',
#    'mouse model',
#    'bile acids',
#    'metabolomics',
#    'metagenomics'],
#   'SQ_TP': ['newborn AND gut microbiota AND bile acids',
#    'newborn AND gut microbiota AND metabolomics'],
#   'SQ_FP': ['bile acids NOT (IBD OR microbiome)',
#    'metabolomics NOT (IBD OR microbiome)',
#    'metagenomics NOT (IBD OR microbiome)'],
#   'SQ_R': ['newborn AND microbiota', 'newborn AND microbiota maturation']},
#  'Type I interferon signaling before hematopoietic stem cell transplantation lowers donor T cell activation via reduced allogenicity of recipient cells': {'Pub Title': 'Type I interferon signaling before hematopoietic stem cell transplantation lowers donor T cell activation via reduced allogenicity of recipient cells',
#   'Keywords': ['IFN-I',
#    'type I interferons',
#    'graft versus host disease',
#    'allogenic hematopoetic stem cell transplanation',
#    'RIG-I',
#    'mouse models',
#    '3pRNA',
#    'conditioning therapy',
#    'dendritic cells',
#    'T cells',
#    'T cell activation'],
#   'SQ_TP': ['IFN-I AND T cell activation AND hematopoetic stemm cell transplantation'],
#   'SQ_FP': ['IFN-I NOT IDB'],
#   'SQ_R': ['allogenic hematopoetic stem cell transplanation AND graft versus host disease']},
#  'Effect of Helicobacter pylori on gastrointestinal microbiota: a population-based study in Linqu, a high-risk area of gastric cancer': {'Pub Title': 'Effect of Helicobacter pylori on gastrointestinal microbiota: a population-based study in Linqu, a high-risk area of gastric cancer',
#   'Keywords': ['Heliobacter pylori',
#    'gastric cancer',
#    'dysbiosis',
#    '16S rRNA',
#    'coexclusion',
#    'Heliobacter',
#    'Fusobacterium',
#    'Neisseria',
#    'Prevotella',
#    'Veillonella',
#    'Rothia',
#    'H. pylori eradication',
#    'failed treatment',
#    'antibiotics',
#    'high pH'],
#   'SQ_TP': ['Heliobacter pylori AND gastric cancer AND microbiota'],
#   'SQ_FP': ['Heliobacter pylori NOT (IBD OR microbiota)'],
#   'SQ_R': ['dysbiosis AND gastric cancer', 'antibiotics AND gastric cancer']},
#  'RIG-I activating immunostimulatory RNA boosts the efficacy of anticancer vaccines and synergizes with immune checkpoint blockade': {'Pub Title': 'RIG-I activating immunostimulatory RNA boosts the efficacy of anticancer vaccines and synergizes with immune checkpoint blockade',
#   'Keywords': ['Immuno-oncology',
#    'Innate immunity',
#    'RIG-I',
#    'immune checkpoint inhibitors',
#    'anti-cancer vaccine',
#    'dendritic cells',
#    '3pRNA',
#    'murine melanoma models',
#    'CTLA-4',
#    'melanoma',
#    'personolized cancer therapy',
#    'T cells'],
#   'SQ_TP': ['RIG-I AND RNA AND anticancer vaccines'],
#   'SQ_FP': ['RIG-I NOT (cancer OR IBD)'],
#   'SQ_R': ['anticancer vaccines AND RNA']},
#  'RIG-I activation is critical for responsiveness to checkpoint blockade': {'Pub Title': 'RIG-I activation is critical for responsiveness to checkpoint blockade',
#   'Keywords': ['immune checkpoint inhibitors',
#    'RIG-I',
#    'caspase 3',
#    'dendritic cells',
#    'CTLA-4',
#    'PD-1',
#    'T cells',
#    'immunotherpay',
#    'DDX58',
#    'transcriptomics',
#    'melanoma',
#    'tumor microenvironment',
#    'mouse model',
#    'tumor cell lines'],
#   'SQ_TP': ['RIG-I AND immunotherapy'],
#   'SQ_FP': ['caspase 3 NOT (cancer OR IBD)'],
#   'SQ_R': ['RIG-I AND cancer']},
#  'Role and Mechanism of Galactose-Alpha-1,3-Galactose in the Elicitation of Delayed Anaphylactic Reactions to Red Meat': {'Pub Title': 'Role and Mechanism of Galactose-Alpha-1,3-Galactose in the Elicitation of Delayed Anaphylactic Reactions to Red Meat',
#   'Keywords': ['Alpha gal',
#    'carbohydrate',
#    'food allergy',
#    'red meat allergy',
#    'tick',
#    'IgE',
#    'IgM',
#    'IgE'],
#   'SQ_TP': ['Alpha gal AND red meat allergy AND tick'],
#   'SQ_FP': ['tick NOT (allergy OR IDB)'],
#   'SQ_R': ['red meat allergy AND tick']},
#  'Targeting tumor-resident mast cells for effective anti-melanoma immune responses': {'Pub Title': 'Targeting tumor-resident mast cells for effective anti-melanoma immune responses',
#   'Keywords': ['immune checkpoint inhibitors',
#    'LPS',
#    'melanoma',
#    'colitis',
#    'CTLA-4',
#    'mouse models',
#    'mast cells',
#    'T cells',
#    'CXCL10',
#    'biomarker',
#    'tumor microenvironment'],
#   'SQ_TP': ['mast cells AND immune checkpoint inhibitors AND melanoma'],
#   'SQ_FP': ['mast cells NOT (cancer OR IBD)'],
#   'SQ_R': ['mast cells  AND melanoma',
#    'immune checkpoint inhibitors AND melanoma']},
#  'Sequence and cultivation study of Muribaculaceae reveals novel species, host preference, and functional potential of this yet undescribed family': {'Pub Title': 'Sequence and cultivation study of Muribaculaceae reveals novel species, host preference, and functional potential of this yet undescribed family',
#   'Keywords': ['S24-7',
#    'mouse gut microbiota',
#    '16S rRNA',
#    'metagenomics',
#    'Muribaculaceae',
#    'Homeothermaceae',
#    'benzoate',
#    'macrolide resistance',
#    'culturabitlity'],
#   'SQ_TP': ['Muribaculaceae AND culturability'],
#   'SQ_FP': ['metagenomics NOT (Muribaculaceae OR IBD OR gut microbiota)'],
#   'SQ_R': ['Homeothermaceae']},
#  'Increased Incidence of Colon Tumors in AOM-Treated Apc1638N/+ Mice Reveals Higher Frequency of Tumor Associated Neutrophils in Colon Than Small Intestine': {'Pub Title': 'Increased Incidence of Colon Tumors in AOM-Treated Apc1638N/+ Mice Reveals Higher Frequency of Tumor Associated Neutrophils in Colon Than Small Intestine',
#   'Keywords': ['colorectal cancer',
#    'mouse model',
#    'adenomatous polyposis coli',
#    'azoxymethane',
#    'tumor immunology',
#    'tumor microenvironment',
#    'tumor associated neutrophils',
#    'tumor associated macrophages',
#    'dendritic cells',
#    'CCL17'],
#   'SQ_TP': ['colorectal cancer AND mouse model AND tumor associated neutrophils AND (AOM OR azoxymethan)'],
#   'SQ_FP': ['mouse model NOT (cancer OR IBD)'],
#   'SQ_R': ['colorectal cancer AND mouse model AND (AOM OR azoxymethan)']}}

# %% [markdown]
# # print dictionary
# keywords_dict

# %% [markdown]
# ##### Other representation of the dictionary for testing and debugging purposes

# %%
for pub_title, data in keywords_dict.items():
            print(f"Pub Title: {data['Pub Title']}")
            print(f"Keywords: {', '.join(data['Keywords'])}")
            print(f"SQ_TP: {', '.join(data['SQ_TP'])}")
            print(f"SQ_FP: {', '.join(data['SQ_FP'])}")
            print(f"SQ_R: {', '.join(data['SQ_R'])}")
            print("\n" + "=" * 80 + "\n")  # Separator between entries
# Out:
# Pub Title: Mitochondrial impairment drives intestinal stem cell transition into dysfunctional Paneth cells predicting Crohn’s disease recurrence.
# Keywords: paneth cells, Crohn's disease, LGR5+ intestinal stemm cells, organoids, TNFΔARE mice, ISC morphological appearance, PC morphological appearance, mitochondrial dysfunction, ileal tissue samples, PC granularity, surgical resection, CD recurrence, CD, PC, intestinal stemm cells
# SQ_TP: (PC or paneth cells) AND (CD or Crohn's disease) AND ISC morphological appearance, (LGR5+) AND (CD or Crohn's disease), ((PC or paneth cells) granularity) AND (CD or Crohn's disease), (CD or Crohn's disease) AND mitochondrial dysfunction
# SQ_FP: (PC or paneth cells) NOT ((CD or Crohn's disease) OR IBD), organoids NOT ((CD or Crohn's disease) OR IBD), surgical resection NOT ((CD or Crohn's disease) OR IBD)
# SQ_R: ((PC or paneth cells) OR (CD or Crohn's disease)) AND organoids, ((PC or paneth cells) OR (CD or Crohn's disease)) AND TNFΔARE mice, (PC or paneth cells) AND (CD or Crohn's disease)
#
# ================================================================================
#
# Pub Title: The Spatial Heterogeneity of the Gut Limits Predation and Fosters Coexistence of Bacteria and Bacteriophages
# Keywords: phage therapy, Mt1B1 E. coli, OMM12 mouse model, phage resistance, spatial refuges, proliferation threshold, phage bacteria coexistence, off-target phage amplification, spatial heterogeneity, coexistance, bacteriophages, gut
# SQ_TP: phage therapy AND spatial refuges AND gut
# SQ_FP: Mt1B1 E. coli AND proliferation threshold NOT gut, OMM12 mouse model NOT gut
# SQ_R: phage bacteria coexistence AND phage therapy, phage therapy AND proliferation threshold AND gut
#
# ================================================================================
#
# Pub Title: Integrated microbiota and metabolite profiles link Crohn's disease to sulfur metabolism
# Keywords: HSCT, autologous hematopoetic stem cell transplantation, Crohn's disease, community richness, community diversity, gnotobiotic humanized mice, multi-omics, metabolites, sulfur metabolism, Desulfovibrio, sulfate-reducing bacteria, Bilophila, Bacteriodes fragilis, functional modules, transition metals transport systems, hematopoetic stem cell transplantation
# SQ_TP: HSCT AND sulfur metabolism AND CD, multi-omics AND CD AND Desulfovibrio, HSCT AND sulfate-reducing bacteria AND CD AND transition metals transport systems
# SQ_FP: multi-omics NOT (CD OR IBD), gnotobiotic humanized mice AND multi-omics NOT (CD or IBD)
# SQ_R: Desulfovibrio AND sulfur metabolism AND CD, multi-omics AND CD AND Desulfovibrio, community richness AND HSCT AND CD
#
# ================================================================================
#
# Pub Title: MCL-1 gains occur with high frequency in lung adenocarcinoma and can be targeted therapeutically
# Keywords: MCL-1, lung adenocarcinoma, NSCLC, murine tumor model, rational drug target, TP53, oncogene addiction, cancer cell lines, organoids, clonal evolution, drug target, cancer
# SQ_TP: MCL-1 AND NSCLC AND drug target, murine tumor model AND MCL-1 AND NSCLC, MCL-1  AND murine tumor model AND oncogene addiction
# SQ_FP: TP53 NOT (NSCLC OR lung adenocarcinoma OR cancer), TP53 NOT (cancer OR IBD)
# SQ_R: (NSCLC OR MCL-1) AND (microbiome)
#
# ================================================================================
#
# Pub Title: MS-Based in Situ Proteomics Reveals AMPylation of Host Proteins during Bacterial Infection
# Keywords: AMPylation, adenylylation, RHO GTPases, Fic, VopS, infection, proteomics, in situ proteomics, pro-N6pA, effector proteins, Vibrio parahaemolyticus
# SQ_TP: (AMPylation or adenylylation) AND infection AND proteomics, (Fic or VopS) AND AMPylation AND infection, pro-N6pA AND in situ proteomics AND infection AND (AMPylation or adenylylation)
# SQ_FP: proteomics NOT (infection OR IBD), Vibrio parahaemolyticus NOT (infection OR IBD), RHO GTPases NOT (infection OR IBD)
# SQ_R: infection AND effector proteins, pro-N6pA AND in situ proteomics AND infection
#
# ================================================================================
#
# Pub Title: Arrhythmic Gut Microbiome Signatures Predict Risk of Type 2 Diabetes
# Keywords: human intestinal microbiota, population-based cohorts, circadian rythms, diurnal oscillations, type 2 diabetes, metagenomics, amplicon sequencing, obesity, machine learning, prediction, microbiome, gut
# SQ_TP: (circadian rythms OR  diurnal oscillations) AND type 2 diabetes AND (microbiome OR metagenomics) AND (prediction OR machine learning)
# SQ_FP: type 2 diabetes NOT microbiome, circadian rythms NOT microbiome, metagenomics NOT microbiome
# SQ_R: type 2 diabetes AND microbiome, metagenomics AND (circadian rythms OR  diurnal oscillations) AND gut, (human intestinal microbiota OR gut OR microbiome) AND prediction AND type 2 diabetes
#
# ================================================================================
#
# Pub Title: The CMV-Specific CD8+ T Cell Response Is Dominated by Supra-Public Clonotypes with High Generation Probabilities
# Keywords: memory inflation, clonotypes, generation probability, T cell response, TCR, convergent recombination, TCR repertoire, cytomegalovirus, mouse model, CMV, public clonotypes
# SQ_TP: public clonotype AND CMV AND (T cell response OR TCR) AND mouse model
# SQ_FP: CMV NOT (clonotype OR IBD), CMV NOT (TCR OR IBD)
# SQ_R: public clonotype AND CMV AND T cell response, clonotype AND (TCR OR T cell response)
#
# ================================================================================
#
# Pub Title: Reverse TCR repertoire evolution toward dominant low-affinity clones during chronic CMV infection
# Keywords: T cell immunity, affnity maturation, clonal selection, TCR, T cell response, cytomegalovirus, chronic infection, senescence, immunopathology, immunotherapy, CMV
# SQ_TP: CMV AND affinity maturation AND low-affinity AND (TCR OR T cell response)
# SQ_FP: CMV NOT ((TCR OR T cell response) OR IBD)
# SQ_R: infection AND affinity maturation AND low-affinity, infection AND clonal selection AND low-affinity
#
# ================================================================================
#
# Pub Title: The gut bacterium Extibacter muris produces secondary bile acids and influences liver physiology in gnotobiotic mice
# Keywords: lipids, bile acids, gut microbiota, synthetic community, Oligo-MM12, Extibacter muris, gut-liver axis, 7α-dehydroxylation, gnotobiotic mouse model, hepatic response, liver physiology, proteomics, mouse model
# SQ_TP: lipids AND Extibacter muris AND bile acids AND mouse model AND proteomics
# SQ_FP: bile acids NOT (gut microbiota OR IBD)
# SQ_R: bile acids AND gut-liver axis AND Extibacter muris, lipids AND gut-liver axis AND Extibacter muris, lipids AND gut-liver axis AND gut microbiota
#
# ================================================================================
#
# Pub Title: A collection of bacterial isolates from the pig intestine reveals functional and taxonomic diversity
# Keywords: pig microbiota, pig gut, 16S rRNA, metagenomics, fucosyltransferase, Clostridium porci, sactipeptides, bile acids, Bullifex porci, MALDI, proteomes
# SQ_TP: pig microbiota AND metagenomics AND MALDI
# SQ_FP: bile acids NOT (pigs OR IBD)
# SQ_R: pig microbiota AND metagenomics AND proteomes, pig gut AND 16S rRNA
#
# ================================================================================
#
# Pub Title: A protease-activated, near-infrared fluorescent probe for early endoscopic detection of premalignant gastrointestinal lesions
# Keywords: Early detection, flourescence, endoscopy, activity-based probe, high-risk patients, gastrointestinal lesions, dysplasia, inflammatory bowel disease, adenoma detection rate, APC mouse model, cathepsin-activated probe
# SQ_TP: flourescent probe AND gastrointestinal lesions AND early detection
# SQ_FP: endoscopy NOT IBD
# SQ_R: gastrointestinal lesions AND early detection, gastrointestinal lesions AND activity-based probe
#
# ================================================================================
#
# Pub Title: Bile acids drive the newborn’s gut microbiota maturation
# Keywords: maternal microbiome, liver maturation, newborn, gut microbiota, microbiota maturation, mouse model, bile acids, metabolomics, metagenomics
# SQ_TP: newborn AND gut microbiota AND bile acids, newborn AND gut microbiota AND metabolomics
# SQ_FP: bile acids NOT (IBD OR microbiome), metabolomics NOT (IBD OR microbiome), metagenomics NOT (IBD OR microbiome)
# SQ_R: newborn AND microbiota, newborn AND microbiota maturation
#
# ================================================================================
#
# Pub Title: Type I interferon signaling before hematopoietic stem cell transplantation lowers donor T cell activation via reduced allogenicity of recipient cells
# Keywords: IFN-I, type I interferons, graft versus host disease, allogenic hematopoetic stem cell transplanation, RIG-I, mouse models, 3pRNA, conditioning therapy, dendritic cells, T cells, T cell activation
# SQ_TP: IFN-I AND T cell activation AND hematopoetic stemm cell transplantation
# SQ_FP: IFN-I NOT IDB
# SQ_R: allogenic hematopoetic stem cell transplanation AND graft versus host disease
#
# ================================================================================
#
# Pub Title: Effect of Helicobacter pylori on gastrointestinal microbiota: a population-based study in Linqu, a high-risk area of gastric cancer
# Keywords: Heliobacter pylori, gastric cancer, dysbiosis, 16S rRNA, coexclusion, Heliobacter, Fusobacterium, Neisseria, Prevotella, Veillonella, Rothia, H. pylori eradication, failed treatment, antibiotics, high pH
# SQ_TP: Heliobacter pylori AND gastric cancer AND microbiota
# SQ_FP: Heliobacter pylori NOT (IBD OR microbiota)
# SQ_R: dysbiosis AND gastric cancer, antibiotics AND gastric cancer
#
# ================================================================================
#
# Pub Title: RIG-I activating immunostimulatory RNA boosts the efficacy of anticancer vaccines and synergizes with immune checkpoint blockade
# Keywords: Immuno-oncology, Innate immunity, RIG-I, immune checkpoint inhibitors, anti-cancer vaccine, dendritic cells, 3pRNA, murine melanoma models, CTLA-4, melanoma, personolized cancer therapy, T cells
# SQ_TP: RIG-I AND RNA AND anticancer vaccines
# SQ_FP: RIG-I NOT (cancer OR IBD)
# SQ_R: anticancer vaccines AND RNA
#
# ================================================================================
#
# Pub Title: RIG-I activation is critical for responsiveness to checkpoint blockade
# Keywords: immune checkpoint inhibitors, RIG-I, caspase 3, dendritic cells, CTLA-4, PD-1, T cells, immunotherpay, DDX58, transcriptomics, melanoma, tumor microenvironment, mouse model, tumor cell lines
# SQ_TP: RIG-I AND immunotherapy
# SQ_FP: caspase 3 NOT (cancer OR IBD)
# SQ_R: RIG-I AND cancer
#
# ================================================================================
#
# Pub Title: Role and Mechanism of Galactose-Alpha-1,3-Galactose in the Elicitation of Delayed Anaphylactic Reactions to Red Meat
# Keywords: Alpha gal, carbohydrate, food allergy, red meat allergy, tick, IgE, IgM, IgE
# SQ_TP: Alpha gal AND red meat allergy AND tick
# SQ_FP: tick NOT (allergy OR IDB)
# SQ_R: red meat allergy AND tick
#
# ================================================================================
#
# Pub Title: Targeting tumor-resident mast cells for effective anti-melanoma immune responses
# Keywords: immune checkpoint inhibitors, LPS, melanoma, colitis, CTLA-4, mouse models, mast cells, T cells, CXCL10, biomarker, tumor microenvironment
# SQ_TP: mast cells AND immune checkpoint inhibitors AND melanoma
# SQ_FP: mast cells NOT (cancer OR IBD)
# SQ_R: mast cells  AND melanoma, immune checkpoint inhibitors AND melanoma
#
# ================================================================================
#
# Pub Title: Sequence and cultivation study of Muribaculaceae reveals novel species, host preference, and functional potential of this yet undescribed family
# Keywords: S24-7, mouse gut microbiota, 16S rRNA, metagenomics, Muribaculaceae, Homeothermaceae, benzoate, macrolide resistance, culturabitlity
# SQ_TP: Muribaculaceae AND culturability
# SQ_FP: metagenomics NOT (Muribaculaceae OR IBD OR gut microbiota)
# SQ_R: Homeothermaceae
#
# ================================================================================
#
# Pub Title: Increased Incidence of Colon Tumors in AOM-Treated Apc1638N/+ Mice Reveals Higher Frequency of Tumor Associated Neutrophils in Colon Than Small Intestine
# Keywords: colorectal cancer, mouse model, adenomatous polyposis coli, azoxymethane, tumor immunology, tumor microenvironment, tumor associated neutrophils, tumor associated macrophages, dendritic cells, CCL17
# SQ_TP: colorectal cancer AND mouse model AND tumor associated neutrophils AND (AOM OR azoxymethan)
# SQ_FP: mouse model NOT (cancer OR IBD)
# SQ_R: colorectal cancer AND mouse model AND (AOM OR azoxymethan)
#
# ================================================================================

# %% [markdown]
# ### Step 3: Use dictionary with queries as input and fetch PubMED IDs.
# #### Option 1: This option is more comprehensive since it also saves the used queries in the dictionary.

# %%
def dict_to_pubmed_id(input_dict):
    # Initialize a new dictionary to store the results
    result_dict = {}

    # Iterate over each publication entry in the input dictionary
    for pub_title, pub_data in input_dict.items():
        # Create a copy of the publication data
        pub_result = pub_data.copy()

        # Initialize empty lists for PubMed IDs for SQ_TP, SQ_FP, and SQ_R
        pub_result['PubMed_IDs_TP'] = []
        pub_result['PubMed_IDs_FP'] = []
        pub_result['PubMed_IDs_R'] = []

        # Extract elements from SQ_TP, SQ_FP, and SQ_R lists and search PubMed for IDs
        for sq_tp_element in pub_data['SQ_TP']:
            pub_result['PubMed_IDs_TP'].extend(search_pubmed_for_ids(sq_tp_element))

        for sq_fp_element in pub_data['SQ_FP']:
            pub_result['PubMed_IDs_FP'].extend(search_pubmed_for_ids(sq_fp_element))

        for sq_r_element in pub_data['SQ_R']:
            pub_result['PubMed_IDs_R'].extend(search_pubmed_for_ids(sq_r_element))

        # Add the modified publication data to the result dictionary
        result_dict[pub_title] = pub_result

    return result_dict

# %%
result_dict = dict_to_pubmed_id(keywords_dict)
result_dict
# Out:
# {'Mitochondrial impairment drives intestinal stem cell transition into dysfunctional Paneth cells predicting Crohn’s disease recurrence.': {'Pub Title': 'Mitochondrial impairment drives intestinal stem cell transition into dysfunctional Paneth cells predicting Crohn’s disease recurrence.',
#   'Keywords': ['paneth cells',
#    "Crohn's disease",
#    'LGR5+ intestinal stemm cells',
#    'organoids',
#    'TNFΔARE mice',
#    'ISC morphological appearance',
#    'PC morphological appearance',
#    'mitochondrial dysfunction',
#    'ileal tissue samples',
#    'PC granularity',
#    'surgical resection',
#    'CD recurrence',
#    'CD',
#    'PC',
#    'intestinal stemm cells'],
#   'SQ_TP': ["(PC or paneth cells) AND (CD or Crohn's disease) AND ISC morphological appearance",
#    "(LGR5+) AND (CD or Crohn's disease)",
#    "((PC or paneth cells) granularity) AND (CD or Crohn's disease)",
#    "(CD or Crohn's disease) AND mitochondrial dysfunction"],
#   'SQ_FP': ["(PC or paneth cells) NOT ((CD or Crohn's disease) OR IBD)",
#    "organoids NOT ((CD or Crohn's disease) OR IBD)",
#    "surgical resection NOT ((CD or Crohn's disease) OR IBD)"],
#   'SQ_R': ["((PC or paneth cells) OR (CD or Crohn's disease)) AND organoids",
#    "((PC or paneth cells) OR (CD or Crohn's disease)) AND TNFΔARE mice",
#    "(PC or paneth cells) AND (CD or Crohn's disease)"],
#   'PubMed_IDs_TP': ['38084837',
#    '37578396',
#    '37167706',
#    '35720495',
#    '35169117',
#    '35158099',
#    '34977371',
#    '34700029',
#    '34549599',
#    '34467981',
#    '34289550',
#    '34160355',
#    '33906557',
#    '38176135',
#    '38161383',
#    '38136224',
#    '38116552',
#    '38103512',
#    '38078655',
#    '38069446',
#    '38030696',
#    '38030136',
#    '37996004',
#    '37978573',
#    '37967787',
#    '37947686'],
#   'PubMed_IDs_FP': ['38183186',
#    '38183155',
#    '38183121',
#    '38183024',
#    '38183010',
#    '38182982',
#    '38182955',
#    '38182951',
#    '38182917',
#    '38182890',
#    '38182816',
#    '38182788',
#    '38182774',
#    '38182890',
#    '38182746',
#    '38182646',
#    '38182554',
#    '38181785',
#    '38181752',
#    '38181751',
#    '38181749',
#    '38181748',
#    '38181746',
#    '38181744',
#    '38181419',
#    '38180686',
#    '38182923',
#    '38182838',
#    '38182527',
#    '38182482',
#    '38182479',
#    '38182465',
#    '38182443',
#    '38181741',
#    '38181580',
#    '38181122',
#    '38181006',
#    '38180912',
#    '38180706'],
#   'PubMed_IDs_R': ['38182890',
#    '38177905',
#    '38151993',
#    '38136224',
#    '38134862',
#    '38114134',
#    '38102821',
#    '38090581',
#    '38090526',
#    '38078655',
#    '38065485',
#    '38039961',
#    '38020881',
#    '37169343',
#    '36821422',
#    '34893805',
#    '34788601',
#    '34350516',
#    '33972436',
#    '32828819',
#    '32679063',
#    '32457323',
#    '32111634',
#    '30327532',
#    '30295722',
#    '28981653',
#    '38174324',
#    '38172618',
#    '38165844',
#    '38163628',
#    '38163288',
#    '38150749',
#    '38142491',
#    '38140261',
#    '38136629',
#    '38130785',
#    '38130588',
#    '38123557',
#    '38118143']},
#  'The Spatial Heterogeneity of the Gut Limits Predation and Fosters Coexistence of Bacteria and Bacteriophages': {'Pub Title': 'The Spatial Heterogeneity of the Gut Limits Predation and Fosters Coexistence of Bacteria and Bacteriophages',
#   'Keywords': ['phage therapy',
#    'Mt1B1 E. coli',
#    'OMM12 mouse model',
#    'phage resistance',
#    'spatial refuges',
#    'proliferation threshold',
#    'phage bacteria coexistence',
#    'off-target phage amplification',
#    'spatial heterogeneity',
#    'coexistance',
#    'bacteriophages',
#    'gut'],
#   'SQ_TP': ['phage therapy AND spatial refuges AND gut'],
#   'SQ_FP': ['Mt1B1 E. coli AND proliferation threshold NOT gut',
#    'OMM12 mouse model NOT gut'],
#   'SQ_R': ['phage bacteria coexistence AND phage therapy',
#    'phage therapy AND proliferation threshold AND gut'],
#   'PubMed_IDs_TP': ['32615090'],
#   'PubMed_IDs_FP': ['34431719', '33927045', '31998276', '31396223'],
#   'PubMed_IDs_R': ['37711678',
#    '37442611',
#    '36225237',
#    '36168737',
#    '35311576',
#    '34925289',
#    '34873551',
#    '34517500',
#    '34020940',
#    '33531404',
#    '32615090',
#    '32576653',
#    '31907203']},
#  "Integrated microbiota and metabolite profiles link Crohn's disease to sulfur metabolism": {'Pub Title': "Integrated microbiota and metabolite profiles link Crohn's disease to sulfur metabolism",
#   'Keywords': ['HSCT',
#    'autologous hematopoetic stem cell transplantation',
#    "Crohn's disease",
#    'community richness',
#    'community diversity',
#    'gnotobiotic humanized mice',
#    'multi-omics',
#    'metabolites',
#    'sulfur metabolism',
#    'Desulfovibrio',
#    'sulfate-reducing bacteria',
#    'Bilophila',
#    'Bacteriodes fragilis',
#    'functional modules',
#    'transition metals transport systems',
#    'hematopoetic stem cell transplantation'],
#   'SQ_TP': ['HSCT AND sulfur metabolism AND CD',
#    'multi-omics AND CD AND Desulfovibrio',
#    'HSCT AND sulfate-reducing bacteria AND CD AND transition metals transport systems'],
#   'SQ_FP': ['multi-omics NOT (CD OR IBD)',
#    'gnotobiotic humanized mice AND multi-omics NOT (CD or IBD)'],
#   'SQ_R': ['Desulfovibrio AND sulfur metabolism AND CD',
#    'multi-omics AND CD AND Desulfovibrio',
#    'community richness AND HSCT AND CD'],
#   'PubMed_IDs_TP': [],
#   'PubMed_IDs_FP': ['38182908',
#    '38182861',
#    '38182825',
#    '38182734',
#    '38182608',
#    '38182575',
#    '38181741',
#    '38181739',
#    '38181610',
#    '38181185',
#    '38180356',
#    '38180342',
#    '38180241',
#    '37627638'],
#   'PubMed_IDs_R': ['35176384',
#    '30277213',
#    '14770302',
#    '9761735',
#    '9568899',
#    '1331321',
#    '2557831',
#    '4093441',
#    '429261']},
#  'MCL-1 gains occur with high frequency in lung adenocarcinoma and can be targeted therapeutically': {'Pub Title': 'MCL-1 gains occur with high frequency in lung adenocarcinoma and can be targeted therapeutically',
#   'Keywords': ['MCL-1',
#    'lung adenocarcinoma',
#    'NSCLC',
#    'murine tumor model',
#    'rational drug target',
#    'TP53',
#    'oncogene addiction',
#    'cancer cell lines',
#    'organoids',
#    'clonal evolution',
#    'drug target',
#    'cancer'],
#   'SQ_TP': ['MCL-1 AND NSCLC AND drug target',
#    'murine tumor model AND MCL-1 AND NSCLC',
#    'MCL-1  AND murine tumor model AND oncogene addiction'],
#   'SQ_FP': ['TP53 NOT (NSCLC OR lung adenocarcinoma OR cancer)',
#    'TP53 NOT (cancer OR IBD)'],
#   'SQ_R': ['(NSCLC OR MCL-1) AND (microbiome)'],
#   'PubMed_IDs_TP': ['37870244',
#    '37470692',
#    '35530162',
#    '35449204',
#    '35069696',
#    '34286518',
#    '33122847',
#    '33039730',
#    '32587776',
#    '32212793',
#    '31117253',
#    '31115521',
#    '31113936',
#    '34913280',
#    '34826601',
#    '33310890',
#    '33122847',
#    '32913197',
#    '32276600',
#    '32189414',
#    '32156781',
#    '32081857',
#    '31662324',
#    '30668360',
#    '30663221',
#    '29360439',
#    '32913197',
#    '25564254',
#    '23243017',
#    '20227039'],
#   'PubMed_IDs_FP': ['38181584',
#    '38181263',
#    '38180132',
#    '38178745',
#    '38178685',
#    '38178682',
#    '38175439',
#    '38173477',
#    '38173453',
#    '38173283',
#    '38156909',
#    '38155543',
#    '38147624',
#    '38181584',
#    '38181263',
#    '38180132',
#    '38178745',
#    '38178685',
#    '38178682',
#    '38175439',
#    '38173477',
#    '38173453',
#    '38173283',
#    '38156909',
#    '38155543',
#    '38147624'],
#   'PubMed_IDs_R': ['38171775',
#    '38132121',
#    '38103007',
#    '38103006',
#    '38074650',
#    '38061593',
#    '38041547',
#    '37999101',
#    '37950236',
#    '37939189',
#    '37894458',
#    '37857525',
#    '37835378']},
#  'MS-Based in Situ Proteomics Reveals AMPylation of Host Proteins during Bacterial Infection': {'Pub Title': 'MS-Based in Situ Proteomics Reveals AMPylation of Host Proteins during Bacterial Infection',
#   'Keywords': ['AMPylation',
#    'adenylylation',
#    'RHO GTPases',
#    'Fic',
#    'VopS',
#    'infection',
#    'proteomics',
#    'in situ proteomics',
#    'pro-N6pA',
#    'effector proteins',
#    'Vibrio parahaemolyticus'],
#   'SQ_TP': ['(AMPylation or adenylylation) AND infection AND proteomics',
#    '(Fic or VopS) AND AMPylation AND infection',
#    'pro-N6pA AND in situ proteomics AND infection AND (AMPylation or adenylylation)'],
#   'SQ_FP': ['proteomics NOT (infection OR IBD)',
#    'Vibrio parahaemolyticus NOT (infection OR IBD)',
#    'RHO GTPases NOT (infection OR IBD)'],
#   'SQ_R': ['infection AND effector proteins',
#    'pro-N6pA AND in situ proteomics AND infection'],
#   'PubMed_IDs_TP': ['37932372',
#    '33259205',
#    '32951817',
#    '32943788',
#    '27076635',
#    '26604261',
#    '26299961',
#    '25739981',
#    '25073739',
#    '24677795',
#    '37932372',
#    '37832807',
#    '36239538',
#    '34975788',
#    '34531089',
#    '34419450',
#    '33563785',
#    '33508040',
#    '33259205',
#    '32123090',
#    '28031489',
#    '27482742',
#    '27138431',
#    '33259205'],
#   'PubMed_IDs_FP': ['38183228',
#    '38183136',
#    '38183102',
#    '38183095',
#    '38183066',
#    '38183057',
#    '38182978',
#    '38182934',
#    '38182877',
#    '38182865',
#    '38182819',
#    '38182797',
#    '38182717',
#    '38151632',
#    '38147133',
#    '38141354',
#    '38138056',
#    '38137237',
#    '38112441',
#    '38111221',
#    '38110613',
#    '38104701',
#    '38066691',
#    '38061528',
#    '38056755',
#    '38047128',
#    '38180080',
#    '38172611',
#    '38150455',
#    '38137009',
#    '38134633',
#    '38126997',
#    '38113334',
#    '38113333',
#    '38113258',
#    '38109551',
#    '38102112',
#    '38098889',
#    '38093387'],
#   'PubMed_IDs_R': ['38176419',
#    '38176008',
#    '38174929',
#    '38172710',
#    '38172621',
#    '38172595',
#    '38171380',
#    '38170765',
#    '38170736',
#    '38170687',
#    '38170666',
#    '38170641',
#    '38170638',
#    '33259205']},
#  'Arrhythmic Gut Microbiome Signatures Predict Risk of Type 2 Diabetes': {'Pub Title': 'Arrhythmic Gut Microbiome Signatures Predict Risk of Type 2 Diabetes',
#   'Keywords': ['human intestinal microbiota',
#    'population-based cohorts',
#    'circadian rythms',
#    'diurnal oscillations',
#    'type 2 diabetes',
#    'metagenomics',
#    'amplicon sequencing',
#    'obesity',
#    'machine learning',
#    'prediction',
#    'microbiome',
#    'gut'],
#   'SQ_TP': ['(circadian rythms OR  diurnal oscillations) AND type 2 diabetes AND (microbiome OR metagenomics) AND (prediction OR machine learning)'],
#   'SQ_FP': ['type 2 diabetes NOT microbiome',
#    'circadian rythms NOT microbiome',
#    'metagenomics NOT microbiome'],
#   'SQ_R': ['type 2 diabetes AND microbiome',
#    'metagenomics AND (circadian rythms OR  diurnal oscillations) AND gut',
#    '(human intestinal microbiota OR gut OR microbiome) AND prediction AND type 2 diabetes'],
#   'PubMed_IDs_TP': ['32619440', '31569518'],
#   'PubMed_IDs_FP': ['38183233',
#    '38183221',
#    '38183083',
#    '38182983',
#    '38182906',
#    '38182871',
#    '38182782',
#    '38182743',
#    '38182742',
#    '38182725',
#    '38182717',
#    '38182645',
#    '38182193',
#    '21993625',
#    '12064375',
#    '9063711',
#    '8761606',
#    '8237444',
#    '1978998',
#    '5490934',
#    '38181963',
#    '38181946',
#    '38180652',
#    '38179742',
#    '38179451',
#    '38179449',
#    '38179151',
#    '38177994',
#    '38177492',
#    '38176300',
#    '38176299',
#    '38175233',
#    '38171202'],
#   'PubMed_IDs_R': ['38182909',
#    '38180642',
#    '38171651',
#    '38169662',
#    '38164418',
#    '38163557',
#    '38163136',
#    '38161953',
#    '38161503',
#    '38159123',
#    '38154959',
#    '38152889',
#    '38149555',
#    '37803714',
#    '37290656',
#    '36155528',
#    '33292949',
#    '32619440',
#    '32430404',
#    '27912059',
#    '38164418',
#    '38107122',
#    '38104813',
#    '38104165',
#    '38059752',
#    '37939738',
#    '37842336',
#    '37739776',
#    '37716292',
#    '37693358',
#    '37675425',
#    '37655471',
#    '37637136']},
#  'The CMV-Specific CD8+ T Cell Response Is Dominated by Supra-Public Clonotypes with High Generation Probabilities': {'Pub Title': 'The CMV-Specific CD8+ T Cell Response Is Dominated by Supra-Public Clonotypes with High Generation Probabilities',
#   'Keywords': ['memory inflation',
#    'clonotypes',
#    'generation probability',
#    'T cell response',
#    'TCR',
#    'convergent recombination',
#    'TCR repertoire',
#    'cytomegalovirus',
#    'mouse model',
#    'CMV',
#    'public clonotypes'],
#   'SQ_TP': ['public clonotype AND CMV AND (T cell response OR TCR) AND mouse model'],
#   'SQ_FP': ['CMV NOT (clonotype OR IBD)', 'CMV NOT (TCR OR IBD)'],
#   'SQ_R': ['public clonotype AND CMV AND T cell response',
#    'clonotype AND (TCR OR T cell response)'],
#   'PubMed_IDs_TP': ['32823573'],
#   'PubMed_IDs_FP': ['38180893',
#    '38180285',
#    '38180168',
#    '38179539',
#    '38176755',
#    '38174305',
#    '38173810',
#    '38170136',
#    '38168845',
#    '38161846',
#    '38161440',
#    '38160700',
#    '38158932',
#    '38180893',
#    '38180285',
#    '38180168',
#    '38179539',
#    '38176755',
#    '38174305',
#    '38173810',
#    '38170136',
#    '38168845',
#    '38161846',
#    '38161440',
#    '38160700',
#    '38158932'],
#   'PubMed_IDs_R': ['34696417',
#    '33101265',
#    '32823573',
#    '31956412',
#    '31616409',
#    '30710048',
#    '30587531',
#    '30487790',
#    '24512815',
#    '22491952',
#    '19017975',
#    '17709536',
#    '16237109',
#    '38181044',
#    '38154666',
#    '38117802',
#    '38112053',
#    '38110410',
#    '38101220',
#    '38095240',
#    '38079306',
#    '38077312',
#    '38068925',
#    '38064511',
#    '38057617',
#    '38055824']},
#  'Reverse TCR repertoire evolution toward dominant low-affinity clones during chronic CMV infection': {'Pub Title': 'Reverse TCR repertoire evolution toward dominant low-affinity clones during chronic CMV infection',
#   'Keywords': ['T cell immunity',
#    'affnity maturation',
#    'clonal selection',
#    'TCR',
#    'T cell response',
#    'cytomegalovirus',
#    'chronic infection',
#    'senescence',
#    'immunopathology',
#    'immunotherapy',
#    'CMV'],
#   'SQ_TP': ['CMV AND affinity maturation AND low-affinity AND (TCR OR T cell response)'],
#   'SQ_FP': ['CMV NOT ((TCR OR T cell response) OR IBD)'],
#   'SQ_R': ['infection AND affinity maturation AND low-affinity',
#    'infection AND clonal selection AND low-affinity'],
#   'PubMed_IDs_TP': ['32205883'],
#   'PubMed_IDs_FP': ['38180893',
#    '38180285',
#    '38180168',
#    '38179539',
#    '38176755',
#    '38174305',
#    '38173810',
#    '38170136',
#    '38161846',
#    '38161440',
#    '38160700',
#    '38158932',
#    '38158813'],
#   'PubMed_IDs_R': ['37951212',
#    '37640732',
#    '36993964',
#    '36725933',
#    '35493512',
#    '35436416',
#    '35098159',
#    '34584693',
#    '34199200',
#    '33010224',
#    '32205883',
#    '32047506',
#    '31899563',
#    '37951212',
#    '37164014',
#    '36993964',
#    '33010224',
#    '32205883',
#    '30761099',
#    '17108271',
#    '11642611',
#    '10946420']},
#  'The gut bacterium Extibacter muris produces secondary bile acids and influences liver physiology in gnotobiotic mice': {'Pub Title': 'The gut bacterium Extibacter muris produces secondary bile acids and influences liver physiology in gnotobiotic mice',
#   'Keywords': ['lipids',
#    'bile acids',
#    'gut microbiota',
#    'synthetic community',
#    'Oligo-MM12',
#    'Extibacter muris',
#    'gut-liver axis',
#    '7α-dehydroxylation',
#    'gnotobiotic mouse model',
#    'hepatic response',
#    'liver physiology',
#    'proteomics',
#    'mouse model'],
#   'SQ_TP': ['lipids AND Extibacter muris AND bile acids AND mouse model AND proteomics'],
#   'SQ_FP': ['bile acids NOT (gut microbiota OR IBD)'],
#   'SQ_R': ['bile acids AND gut-liver axis AND Extibacter muris',
#    'lipids AND gut-liver axis AND Extibacter muris',
#    'lipids AND gut-liver axis AND gut microbiota'],
#   'PubMed_IDs_TP': ['33382950'],
#   'PubMed_IDs_FP': ['38182391',
#    '38181850',
#    '38180003',
#    '38176339',
#    '38174087',
#    '38173072',
#    '38172739',
#    '38172482',
#    '38172440',
#    '38172157',
#    '38170788',
#    '38169949',
#    '38166966'],
#   'PubMed_IDs_R': ['33382950',
#    '33382950',
#    '38176639',
#    '38161012',
#    '38159754',
#    '38157803',
#    '38152123',
#    '38151562',
#    '38142738',
#    '38139382',
#    '38134985',
#    '38099485',
#    '38072206',
#    '38064669',
#    '38053727']},
#  'A collection of bacterial isolates from the pig intestine reveals functional and taxonomic diversity': {'Pub Title': 'A collection of bacterial isolates from the pig intestine reveals functional and taxonomic diversity',
#   'Keywords': ['pig microbiota',
#    'pig gut',
#    '16S rRNA',
#    'metagenomics',
#    'fucosyltransferase',
#    'Clostridium porci',
#    'sactipeptides',
#    'bile acids',
#    'Bullifex porci',
#    'MALDI',
#    'proteomes'],
#   'SQ_TP': ['pig microbiota AND metagenomics AND MALDI'],
#   'SQ_FP': ['bile acids NOT (pigs OR IBD)'],
#   'SQ_R': ['pig microbiota AND metagenomics AND proteomes',
#    'pig gut AND 16S rRNA'],
#   'PubMed_IDs_TP': ['35650232'],
#   'PubMed_IDs_FP': ['38182391',
#    '38181850',
#    '38180003',
#    '38176933',
#    '38176339',
#    '38174933',
#    '38174087',
#    '38173072',
#    '38172739',
#    '38172482',
#    '38172440',
#    '38172157',
#    '38171973'],
#   'PubMed_IDs_R': ['35216552',
#    '34370660',
#    '33188211',
#    '32630095',
#    '26900430',
#    '26091682',
#    '38173670',
#    '38136849',
#    '38136184',
#    '38133228',
#    '38131029',
#    '38115159',
#    '38032532',
#    '37999473',
#    '37982990',
#    '37970497',
#    '37958078',
#    '37957747',
#    '37928663']},
#  'A protease-activated, near-infrared fluorescent probe for early endoscopic detection of premalignant gastrointestinal lesions': {'Pub Title': 'A protease-activated, near-infrared fluorescent probe for early endoscopic detection of premalignant gastrointestinal lesions',
#   'Keywords': ['Early detection',
#    'flourescence',
#    'endoscopy',
#    'activity-based probe',
#    'high-risk patients',
#    'gastrointestinal lesions',
#    'dysplasia',
#    'inflammatory bowel disease',
#    'adenoma detection rate',
#    'APC mouse model',
#    'cathepsin-activated probe'],
#   'SQ_TP': ['flourescent probe AND gastrointestinal lesions AND early detection'],
#   'SQ_FP': ['endoscopy NOT IBD'],
#   'SQ_R': ['gastrointestinal lesions AND early detection',
#    'gastrointestinal lesions AND activity-based probe'],
#   'PubMed_IDs_TP': [],
#   'PubMed_IDs_FP': ['38183142',
#    '38182749',
#    '38182713',
#    '38182257',
#    '38182188',
#    '38182155',
#    '38182137',
#    '38181182',
#    '38180367',
#    '38180098',
#    '38179876',
#    '38179804',
#    '38179758'],
#   'PubMed_IDs_R': ['38176280',
#    '38173715',
#    '38173110',
#    '38166726',
#    '38161555',
#    '38147615',
#    '38144533',
#    '38140934',
#    '38130477',
#    '38115019',
#    '38110887',
#    '38094039',
#    '38064861',
#    '33443161']},
#  'Bile acids drive the newborn’s gut microbiota maturation': {'Pub Title': 'Bile acids drive the newborn’s gut microbiota maturation',
#   'Keywords': ['maternal microbiome',
#    'liver maturation',
#    'newborn',
#    'gut microbiota',
#    'microbiota maturation',
#    'mouse model',
#    'bile acids',
#    'metabolomics',
#    'metagenomics'],
#   'SQ_TP': ['newborn AND gut microbiota AND bile acids',
#    'newborn AND gut microbiota AND metabolomics'],
#   'SQ_FP': ['bile acids NOT (IBD OR microbiome)',
#    'metabolomics NOT (IBD OR microbiome)',
#    'metagenomics NOT (IBD OR microbiome)'],
#   'SQ_R': ['newborn AND microbiota', 'newborn AND microbiota maturation'],
#   'PubMed_IDs_TP': ['38057706',
#    '37933481',
#    '37480336',
#    '37424334',
#    '37384590',
#    '37242222',
#    '37184522',
#    '36860489',
#    '36843227',
#    '36275061',
#    '36089004',
#    '35782134',
#    '35643532',
#    '38167140',
#    '38014964',
#    '38004243',
#    '37907561',
#    '37845612',
#    '37803605',
#    '37741825',
#    '37652940',
#    '37424334',
#    '37327780',
#    '37242222',
#    '37184522',
#    '37169786'],
#   'PubMed_IDs_FP': ['38182391',
#    '38181850',
#    '38180003',
#    '38176339',
#    '38174087',
#    '38173072',
#    '38172739',
#    '38172482',
#    '38172440',
#    '38172157',
#    '38166966',
#    '38166795',
#    '38166630',
#    '38183083',
#    '38182934',
#    '38182928',
#    '38182899',
#    '38182391',
#    '38182390',
#    '38182389',
#    '38182346',
#    '38182034',
#    '38181937',
#    '38181918',
#    '38181883',
#    '38181882',
#    '38181963',
#    '38181946',
#    '38180652',
#    '38179742',
#    '38179451',
#    '38179449',
#    '38179151',
#    '38177994',
#    '38177492',
#    '38176300',
#    '38176299',
#    '38175233',
#    '38171202'],
#   'PubMed_IDs_R': ['38179333',
#    '38170702',
#    '38167140',
#    '38160470',
#    '38143275',
#    '38136091',
#    '38133242',
#    '38116652',
#    '38115131',
#    '38111204',
#    '38106467',
#    '38104514',
#    '38100452',
#    '38111204',
#    '38104514',
#    '38086952',
#    '38014964',
#    '38010080',
#    '37960297',
#    '37932773',
#    '37845612',
#    '37772676',
#    '37764826',
#    '37753696',
#    '37675422',
#    '37626020']},
#  'Type I interferon signaling before hematopoietic stem cell transplantation lowers donor T cell activation via reduced allogenicity of recipient cells': {'Pub Title': 'Type I interferon signaling before hematopoietic stem cell transplantation lowers donor T cell activation via reduced allogenicity of recipient cells',
#   'Keywords': ['IFN-I',
#    'type I interferons',
#    'graft versus host disease',
#    'allogenic hematopoetic stem cell transplanation',
#    'RIG-I',
#    'mouse models',
#    '3pRNA',
#    'conditioning therapy',
#    'dendritic cells',
#    'T cells',
#    'T cell activation'],
#   'SQ_TP': ['IFN-I AND T cell activation AND hematopoetic stemm cell transplantation'],
#   'SQ_FP': ['IFN-I NOT IDB'],
#   'SQ_R': ['allogenic hematopoetic stem cell transplanation AND graft versus host disease'],
#   'PubMed_IDs_TP': [],
#   'PubMed_IDs_FP': ['38174776',
#    '38172627',
#    '38170154',
#    '38169382',
#    '38168435',
#    '38168230',
#    '38164186',
#    '38162654',
#    '38162640',
#    '38161237',
#    '38160960',
#    '38154666',
#    '38152396'],
#   'PubMed_IDs_R': []},
#  'Effect of Helicobacter pylori on gastrointestinal microbiota: a population-based study in Linqu, a high-risk area of gastric cancer': {'Pub Title': 'Effect of Helicobacter pylori on gastrointestinal microbiota: a population-based study in Linqu, a high-risk area of gastric cancer',
#   'Keywords': ['Heliobacter pylori',
#    'gastric cancer',
#    'dysbiosis',
#    '16S rRNA',
#    'coexclusion',
#    'Heliobacter',
#    'Fusobacterium',
#    'Neisseria',
#    'Prevotella',
#    'Veillonella',
#    'Rothia',
#    'H. pylori eradication',
#    'failed treatment',
#    'antibiotics',
#    'high pH'],
#   'SQ_TP': ['Heliobacter pylori AND gastric cancer AND microbiota'],
#   'SQ_FP': ['Heliobacter pylori NOT (IBD OR microbiota)'],
#   'SQ_R': ['dysbiosis AND gastric cancer', 'antibiotics AND gastric cancer'],
#   'PubMed_IDs_TP': [],
#   'PubMed_IDs_FP': ['37383139',
#    '36677061',
#    '36159425',
#    '35762179',
#    '35587262',
#    '35463722',
#    '35276075',
#    '34684433',
#    '34476755',
#    '34472649',
#    '33673069',
#    '33204185',
#    '32606938'],
#   'PubMed_IDs_R': ['38151037',
#    '38102837',
#    '37997816',
#    '37890493',
#    '37881317',
#    '37846989',
#    '37841431',
#    '37796746',
#    '37712669',
#    '37588796',
#    '37583514',
#    '37565604',
#    '37063848',
#    '38176008',
#    '38162062',
#    '38157006',
#    '38147605',
#    '38137996',
#    '38131043',
#    '38129996',
#    '38069041',
#    '38043750',
#    '38037736',
#    '38032415',
#    '38007073',
#    '38004670']},
#  'RIG-I activating immunostimulatory RNA boosts the efficacy of anticancer vaccines and synergizes with immune checkpoint blockade': {'Pub Title': 'RIG-I activating immunostimulatory RNA boosts the efficacy of anticancer vaccines and synergizes with immune checkpoint blockade',
#   'Keywords': ['Immuno-oncology',
#    'Innate immunity',
#    'RIG-I',
#    'immune checkpoint inhibitors',
#    'anti-cancer vaccine',
#    'dendritic cells',
#    '3pRNA',
#    'murine melanoma models',
#    'CTLA-4',
#    'melanoma',
#    'personolized cancer therapy',
#    'T cells'],
#   'SQ_TP': ['RIG-I AND RNA AND anticancer vaccines'],
#   'SQ_FP': ['RIG-I NOT (cancer OR IBD)'],
#   'SQ_R': ['anticancer vaccines AND RNA'],
#   'PubMed_IDs_TP': ['34006895',
#    '31463653',
#    '30906666',
#    '30852164',
#    '25950488',
#    '20930504'],
#   'PubMed_IDs_FP': ['38182800',
#    '38177117',
#    '38176614',
#    '38176419',
#    '38172511',
#    '38170494',
#    '38161589',
#    '38152396',
#    '38140617',
#    '38118451',
#    '38095472',
#    '38068579',
#    '38060409'],
#   'PubMed_IDs_R': ['38140019',
#    '38067293',
#    '37990414',
#    '37853118',
#    '37837401',
#    '37834126',
#    '37782471',
#    '37773210',
#    '37608695',
#    '37515042',
#    '37476482',
#    '37424627',
#    '37393866']},
#  'RIG-I activation is critical for responsiveness to checkpoint blockade': {'Pub Title': 'RIG-I activation is critical for responsiveness to checkpoint blockade',
#   'Keywords': ['immune checkpoint inhibitors',
#    'RIG-I',
#    'caspase 3',
#    'dendritic cells',
#    'CTLA-4',
#    'PD-1',
#    'T cells',
#    'immunotherpay',
#    'DDX58',
#    'transcriptomics',
#    'melanoma',
#    'tumor microenvironment',
#    'mouse model',
#    'tumor cell lines'],
#   'SQ_TP': ['RIG-I AND immunotherapy'],
#   'SQ_FP': ['caspase 3 NOT (cancer OR IBD)'],
#   'SQ_R': ['RIG-I AND cancer'],
#   'PubMed_IDs_TP': ['38177117',
#    '38172511',
#    '38136298',
#    '38039379',
#    '38023563',
#    '37867244',
#    '37783390',
#    '37758653',
#    '37657445',
#    '37654972',
#    '37612043',
#    '37600811',
#    '37553896'],
#   'PubMed_IDs_FP': ['38183099',
#    '38182957',
#    '38182570',
#    '38181758',
#    '38179003',
#    '38178681',
#    '38178196',
#    '38177717',
#    '38176345',
#    '38176135',
#    '38172276',
#    '38172265',
#    '38171774'],
#   'PubMed_IDs_R': ['38152606',
#    '38151171',
#    '38136298',
#    '38051955',
#    '38039379',
#    '38023563',
#    '38001254',
#    '37988925',
#    '37947765',
#    '37940417',
#    '37934668',
#    '37934086',
#    '37867244']},
#  'Role and Mechanism of Galactose-Alpha-1,3-Galactose in the Elicitation of Delayed Anaphylactic Reactions to Red Meat': {'Pub Title': 'Role and Mechanism of Galactose-Alpha-1,3-Galactose in the Elicitation of Delayed Anaphylactic Reactions to Red Meat',
#   'Keywords': ['Alpha gal',
#    'carbohydrate',
#    'food allergy',
#    'red meat allergy',
#    'tick',
#    'IgE',
#    'IgM',
#    'IgE'],
#   'SQ_TP': ['Alpha gal AND red meat allergy AND tick'],
#   'SQ_FP': ['tick NOT (allergy OR IDB)'],
#   'SQ_R': ['red meat allergy AND tick'],
#   'PubMed_IDs_TP': ['38135009',
#    '38049505',
#    '38014105',
#    '38010429',
#    '37922649',
#    '37838514',
#    '37788844',
#    '37545316',
#    '37498792',
#    '37498787',
#    '37468955',
#    '37455690',
#    '37201681'],
#   'PubMed_IDs_FP': ['38182887',
#    '38182821',
#    '38182760',
#    '38182649',
#    '38179914',
#    '38179629',
#    '38179546',
#    '38179426',
#    '38179129',
#    '38179077',
#    '38178247',
#    '38177212',
#    '38176737'],
#   'PubMed_IDs_R': ['38135009',
#    '38049505',
#    '38014105',
#    '38010429',
#    '37922649',
#    '37838514',
#    '37788844',
#    '37545316',
#    '37504634',
#    '37498792',
#    '37498787',
#    '37468955',
#    '37455690']},
#  'Targeting tumor-resident mast cells for effective anti-melanoma immune responses': {'Pub Title': 'Targeting tumor-resident mast cells for effective anti-melanoma immune responses',
#   'Keywords': ['immune checkpoint inhibitors',
#    'LPS',
#    'melanoma',
#    'colitis',
#    'CTLA-4',
#    'mouse models',
#    'mast cells',
#    'T cells',
#    'CXCL10',
#    'biomarker',
#    'tumor microenvironment'],
#   'SQ_TP': ['mast cells AND immune checkpoint inhibitors AND melanoma'],
#   'SQ_FP': ['mast cells NOT (cancer OR IBD)'],
#   'SQ_R': ['mast cells  AND melanoma',
#    'immune checkpoint inhibitors AND melanoma'],
#   'PubMed_IDs_TP': ['37875043', '33436641', '32810393', '27349976'],
#   'PubMed_IDs_FP': ['38182845',
#    '38180100',
#    '38179277',
#    '38178883',
#    '38178813',
#    '38176933',
#    '38176579',
#    '38176389',
#    '38176167',
#    '38175326',
#    '38174112',
#    '38173156',
#    '38172251'],
#   'PubMed_IDs_R': ['38108072',
#    '37924526',
#    '37875043',
#    '37536185',
#    '37372988',
#    '37256147',
#    '37128790',
#    '37004045',
#    '36974825',
#    '36912943',
#    '36875999',
#    '36644179',
#    '36627143',
#    '38181776',
#    '38180971',
#    '38179007',
#    '38175659',
#    '38171113',
#    '38170160',
#    '38167503',
#    '38166970',
#    '38164757',
#    '38164720',
#    '38161546',
#    '38158454',
#    '38158377']},
#  'Sequence and cultivation study of Muribaculaceae reveals novel species, host preference, and functional potential of this yet undescribed family': {'Pub Title': 'Sequence and cultivation study of Muribaculaceae reveals novel species, host preference, and functional potential of this yet undescribed family',
#   'Keywords': ['S24-7',
#    'mouse gut microbiota',
#    '16S rRNA',
#    'metagenomics',
#    'Muribaculaceae',
#    'Homeothermaceae',
#    'benzoate',
#    'macrolide resistance',
#    'culturabitlity'],
#   'SQ_TP': ['Muribaculaceae AND culturability'],
#   'SQ_FP': ['metagenomics NOT (Muribaculaceae OR IBD OR gut microbiota)'],
#   'SQ_R': ['Homeothermaceae'],
#   'PubMed_IDs_TP': ['38053550',
#    '37985238',
#    '37942687',
#    '37940330',
#    '37894951',
#    '37453492',
#    '37154337',
#    '36364738',
#    '36068389',
#    '35704120',
#    '35266814',
#    '34878098',
#    '34851167'],
#   'PubMed_IDs_FP': ['38182885',
#    '38182754',
#    '38181963',
#    '38181946',
#    '38180652',
#    '38179742',
#    '38179476',
#    '38179451',
#    '38179449',
#    '38179444',
#    '38179151',
#    '38178148',
#    '38177994'],
#   'PubMed_IDs_R': ['32687462',
#    '31195972',
#    '30782206',
#    '30007544',
#    '28815303',
#    '27388460']},
#  'Increased Incidence of Colon Tumors in AOM-Treated Apc1638N/+ Mice Reveals Higher Frequency of Tumor Associated Neutrophils in Colon Than Small Intestine': {'Pub Title': 'Increased Incidence of Colon Tumors in AOM-Treated Apc1638N/+ Mice Reveals Higher Frequency of Tumor Associated Neutrophils in Colon Than Small Intestine',
#   'Keywords': ['colorectal cancer',
#    'mouse model',
#    'adenomatous polyposis coli',
#    'azoxymethane',
#    'tumor immunology',
#    'tumor microenvironment',
#    'tumor associated neutrophils',
#    'tumor associated macrophages',
#    'dendritic cells',
#    'CCL17'],
#   'SQ_TP': ['colorectal cancer AND mouse model AND tumor associated neutrophils AND (AOM OR azoxymethan)'],
#   'SQ_FP': ['mouse model NOT (cancer OR IBD)'],
#   'SQ_R': ['colorectal cancer AND mouse model AND (AOM OR azoxymethan)'],
#   'PubMed_IDs_TP': ['31681563',
#    '31607540',
#    '30550822',
#    '29259703',
#    '23272179',
#    '22922255'],
#   'PubMed_IDs_FP': ['38182911',
#    '38182836',
#    '38182822',
#    '38182777',
#    '38182693',
#    '38182631',
#    '38182610',
#    '38182603',
#    '38182417',
#    '38182404',
#    '38182383',
#    '38182381',
#    '38182371'],
#   'PubMed_IDs_R': ['38173486',
#    '38172689',
#    '38164977',
#    '38142837',
#    '38134478',
#    '38110638',
#    '38103106',
#    '38101774',
#    '38091080',
#    '38090485',
#    '38074634',
#    '38068869',
#    '38040838']}}

# %% [markdown]
# #### Option 2: This one only writes the PubMed id's in the dictionary and not the used queries

# %% [markdown]
# def dict_to_pubmed_id_reduced(input_dict):
#     # Initialize a new dictionary to store the results
#     result_dict = {}
#
#     # Iterate over each publication entry in the input dictionary
#     for pub_title, pub_data in input_dict.items():
#         # Initialize a dictionary to store PubMed IDs and Pub Title
#         pub_result = {'Pub Title': pub_title}
#
#         # Initialize empty lists for PubMed IDs for SQ_TP, SQ_FP, and SQ_R
#         pub_result['PubMed_IDs_TP'] = []
#         pub_result['PubMed_IDs_FP'] = []
#         pub_result['PubMed_IDs_R'] = []
#
#         # Extract elements from SQ_TP, SQ_FP, and SQ_R lists and search PubMed for IDs
#         for sq_tp_element in pub_data['SQ_TP']:
#             pub_result['PubMed_IDs_TP'].extend(search_pubmed_for_ids(sq_tp_element))
#
#         for sq_fp_element in pub_data['SQ_FP']:
#             pub_result['PubMed_IDs_FP'].extend(search_pubmed_for_ids(sq_fp_element))
#
#         for sq_r_element in pub_data['SQ_R']:
#             pub_result['PubMed_IDs_R'].extend(search_pubmed_for_ids(sq_r_element))
#
#         # Add the modified publication data to the result dictionary
#         result_dict[pub_title] = pub_result
#
#     return result_dict

# %% [markdown]
# result2_dict = dict_to_pubmed_id_reduced(keywords_dict)
# result2_dict

# %% [markdown]
# #### Step 4: export dictionaries as xml and json files

# %%
import json
import xml.etree.ElementTree as ET

# %%
# Convert to JSON
json_data = json.dumps(result_dict, indent=2)

# Save to a JSON file
with open("output_ID2.json", "w") as json_file:
    json_file.write(json_data)

# %%
# Convert to XML
def save_result_dict_to_xml(result_dict, xml_file_path):
    # Create the root element
    root = ET.Element("result_dict")

    # Iterate over each publication entry in the result dictionary
    for pub_title, pub_result in result_dict.items():
        entry = ET.SubElement(root, "entry")
        ET.SubElement(entry, "PubTitle").text = pub_result['Pub Title']

        # Add PubMed IDs for SQ_TP
        sq_tp = ET.SubElement(entry, "PubMed_IDs_TP")
        for pubmed_id in pub_result['PubMed_IDs_TP']:
            ET.SubElement(sq_tp, "PubMed_ID").text = pubmed_id

        # Add PubMed IDs for SQ_FP
        sq_fp = ET.SubElement(entry, "PubMed_IDs_FP")
        for pubmed_id in pub_result['PubMed_IDs_FP']:
            ET.SubElement(sq_fp, "PubMed_ID").text = pubmed_id

        # Add PubMed IDs for SQ_R
        sq_r = ET.SubElement(entry, "PubMed_IDs_R")
        for pubmed_id in pub_result['PubMed_IDs_R']:
            ET.SubElement(sq_r, "PubMed_ID").text = pubmed_id

    # Create the XML tree
    xml_tree = ET.ElementTree(root)

    # Save the XML tree to the specified file
    xml_tree.write(xml_file_path)

# %%
# Specify the path for the XML file
xml_file_path = "output.xml"

# Save the result_dict to an XML file
save_result_dict_to_xml(result_dict, xml_file_path)

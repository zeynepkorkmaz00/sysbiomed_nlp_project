# %%
import os
import shutil
import pandas as pd
import glob

# %%
# function that reads SQ pmcids from a csv file and returns a list of pmcids
def read_pmcids_from_csv(input_dir):
    csv_files = glob.glob(os.path.join(input_dir, "PMC*.csv"))
    dfs = []

    # Iterate over each CSV file
    for file in csv_files:
        # Read the CSV file into a dataframe
        df = pd.read_csv(file)
        # Append the dataframe to the list
        dfs.append(df)

    # Concatenate all dataframes in the list into a single dataframe (PMC_IDs_TP column contains one long string of PMC_IDs not lists => helper function needed)
    combined_df = pd.concat(dfs)

    # Helper function to extract and clean PMC_IDs from a given column
    def extract_pmcids(column_name):
        pmc_ids_column = combined_df[column_name].tolist()
        pmc_ids = []
        for string in pmc_ids_column:
            if isinstance(string, str):
                list = string.split(',')
                pmc_ids.append(list)
        pmc_ids = [string.replace(" ", "") for sublist in pmc_ids for string in sublist]
        pmc_ids = ['PMC' + string for string in pmc_ids]
        return pmc_ids

    # Use the helper function for each of the columns
    TP_PMC_IDs = extract_pmcids('PMC_IDs_TP')
    FP_PMC_IDs = extract_pmcids('PMC_IDs_FP')
    R_PMC_IDs = extract_pmcids('PMC_IDs_FP')

    return TP_PMC_IDs, FP_PMC_IDs, R_PMC_IDs

# %%
input_dir = '/Users/tillohlendorf/Downloads/SQ_PMCs'
TP_PMC_IDs, FP_PMC_IDs,R_PMC_IDs = read_pmcids_from_csv(input_dir)

# %%
# few pmc ids smaller than PMC6
TP_PMC_IDs.sort(reverse=True)

# %%
def copy_files(input_dir, input_set_pmcids, output_dir):
    # create output dir if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # set of pmcids that have already been found
    previously_found_pmcids = set()

    for subdir, _, files in os.walk(input_dir):  
        for file in files:
            if file.endswith('.txt'):
                file_path = os.path.join(subdir, file)
                file_name = file.split('.')[0]
                # check if file is in input set of pmcids
                if file_name in input_set_pmcids and file_name not in previously_found_pmcids:
                    shutil.copy(file_path, os.path.join(output_dir, file))
                    print(f'Copied {file_name} to {output_dir}')
                    previously_found_pmcids.add(file_name)

def extract_SQ_txt_files(input_dir, input_list_TP_pmcids, input_list_FP_pmcids, input_list_R_pmcids, output_dir_TP, output_dir_FP, output_dir_R):
    copy_files(input_dir, set(input_list_TP_pmcids), output_dir_TP)
    copy_files(input_dir, set(input_list_FP_pmcids), output_dir_FP)
    copy_files(input_dir, set(input_list_R_pmcids), output_dir_R)

# %%
input_dir = '/Users/tillohlendorf/Downloads/PMC009xxxxxx'
input_list_TP_pmcids = TP_PMC_IDs
input_list_FP_pmcids = FP_PMC_IDs
input_list_R_pmcids = R_PMC_IDs
output_dir_TP = '/Users/tillohlendorf/Downloads/PMC009_TP'
output_dir_FP = '/Users/tillohlendorf/Downloads/PMC009_FP'
output_dir_R = '/Users/tillohlendorf/Downloads/PMC009_R'
extract_SQ_txt_files(input_dir, input_list_TP_pmcids, input_list_FP_pmcids, input_list_R_pmcids, output_dir_TP, output_dir_FP, output_dir_R)
# Out:
# Copied PMC9931718 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9697263 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9040589 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9572914 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9097414 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9926847 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9967826 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9404854 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9778933 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9909292 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9410360 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9538375 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9920414 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9196899 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9159811 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9887734 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9857267 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9708346 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9709273 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9779031 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9960958 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9531436 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9207452 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9548122 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9944430 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9811586 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9991351 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9917337 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9649726 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9345896 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9953403 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9855674 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9486099 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9780445 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9656981 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9962967 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9798587 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9809056 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9511723 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9797572 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9669451 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9100044 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9551995 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9723798 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9048412 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9886688 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9708443 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9026731 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9551612 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9927453 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9697819 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9036297 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9608452 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9542864 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9532165 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9831965 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9368807 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9994512 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9386263 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9413235 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9980611 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9995591 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9877058 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9890194 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9994480 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9309365 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9540502 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9546826 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9855960 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9414437 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9979440 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9493362 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9549136 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9996308 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9998046 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9550512 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9739508 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9539765 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9318041 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9782203 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9536736 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9317776 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9100503 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9414019 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9858301 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9821173 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9874984 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9750998 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9547521 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9468934 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9992544 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9693486 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9164269 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9035740 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9559486 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9047473 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9920731 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9820724 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9973195 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9730714 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9682198 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9571057 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9795194 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9527826 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9523894 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9880963 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9829307 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9549250 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9864076 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9818817 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9274501 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9671473 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9499605 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9906427 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9920184 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9308782 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9520533 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9965155 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9671505 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9810535 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9504724 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9881416 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9638851 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9010389 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9145820 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9632171 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9781426 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9769830 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9417761 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9856405 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9856377 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9961083 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9963870 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9765748 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9519015 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9741991 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9140143 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9430243 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9957889 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9358401 to /Users/tillohlendorf/Downloads/PMC009_TP
# Copied PMC9675190 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9306174 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9698959 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9853002 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9887285 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9392714 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9860967 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9620741 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9602709 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9036178 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9576740 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9105997 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9131011 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9951616 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9737809 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9861059 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9902918 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9658148 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9138178 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9868864 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9491525 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9104722 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9561365 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9798023 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9786745 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9630232 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9164404 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9757081 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9968132 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9784232 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9953403 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9855847 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9945843 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9138768 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9809056 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9355375 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9999379 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9782803 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9715604 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9009260 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9022225 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9500663 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9927453 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9063094 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9789788 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9910956 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9024294 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9413962 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9980611 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9863213 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9569184 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9959343 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9730673 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9188749 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9998046 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9607633 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9512245 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9322646 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9686449 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9561691 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9807604 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9860462 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9389360 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9858301 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9971977 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9503808 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9969057 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9568529 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9687752 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9216733 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9864629 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9942572 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9926786 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9152137 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9994491 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9455863 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9360315 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9913703 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9999573 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9805014 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9475032 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9927464 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9941534 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9415507 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9460100 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9369223 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9899844 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9829175 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9433567 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9899885 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9254412 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9504724 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9740486 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9996383 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9758169 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9806342 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9836087 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9543091 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9402230 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9454102 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9961083 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9229204 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9627790 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9932021 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9496650 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9992732 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9665402 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9794821 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9382244 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9103047 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9815714 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9813417 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9754190 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9684776 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9716758 to /Users/tillohlendorf/Downloads/PMC009_FP
# Copied PMC9675190 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9306174 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9698959 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9853002 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9887285 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9392714 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9860967 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9620741 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9602709 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9036178 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9576740 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9105997 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9131011 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9951616 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9737809 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9861059 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9902918 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9658148 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9138178 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9868864 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9491525 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9104722 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9561365 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9798023 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9786745 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9630232 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9164404 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9757081 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9968132 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9784232 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9953403 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9855847 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9945843 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9138768 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9809056 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9355375 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9999379 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9782803 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9715604 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9009260 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9022225 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9500663 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9927453 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9063094 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9789788 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9910956 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9024294 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9413962 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9980611 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9863213 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9569184 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9959343 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9730673 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9188749 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9998046 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9607633 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9512245 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9322646 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9686449 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9561691 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9807604 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9860462 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9389360 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9858301 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9971977 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9503808 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9969057 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9568529 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9687752 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9216733 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9864629 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9942572 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9926786 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9152137 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9994491 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9455863 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9360315 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9913703 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9999573 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9805014 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9475032 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9927464 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9941534 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9415507 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9460100 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9369223 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9899844 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9829175 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9433567 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9899885 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9254412 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9504724 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9740486 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9996383 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9758169 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9806342 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9836087 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9543091 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9402230 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9454102 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9961083 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9229204 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9627790 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9932021 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9496650 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9992732 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9665402 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9794821 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9382244 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9103047 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9815714 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9813417 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9754190 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9684776 to /Users/tillohlendorf/Downloads/PMC009_R
# Copied PMC9716758 to /Users/tillohlendorf/Downloads/PMC009_R
